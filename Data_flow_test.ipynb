# %%
import requests
import json
from datetime import datetime
#import findspark
#findspark.init('/opt/spark-3.5.1-bin-hadoop3')
#from pyspark.sql import SparkSession
#from pyspark.sql.types import *
#from pyspark.sql.functions import *
from minio import Minio
from io import BytesIO
import pandas as pd
import os
from geopy.geocoders import Nominatim, GoogleV3
from geopy.extra.rate_limiter import RateLimiter
from sqlalchemy import create_engine, MetaData, Table, insert, select, text
from sqlalchemy.exc import OperationalError, SQLAlchemyError
from sqlalchemy.dialects.postgresql import insert as pg_insert

# %%
### Configs API ###

# Base URL
api_url = "https://broker.fiware.urbanplatform.portodigital.pt/v2/entities"

# API params
api_params = {
    'q': 'allowedVehicleType==twoWheeledVehicle',
    'type': 'OnStreetParking',
    'limit': '1000'
}

# Postcode matching URL
match_postcode_url = 'https://raw.githubusercontent.com/dssg-pt/mp-mapeamento-cp7/main/output_data/cod_post_freg_matched.csv'

####### Configs MinIO ########

# Define the MinIO endpoint URL and access keys
minio_endpoint = "localhost:9000"
access_key = "admin"
secret_key = "password123"

# Get current date
date = datetime.today().strftime('%Y%m%d%H%M%S')

# Define the bucket name and object name
bucket_name = "raw"
object_name = f"twowheel/twowheel{date}.json"

output_bucket_name = "preprocessed"

# %% [markdown]
# # 1. Save raw Json to bucket

# %%
# Function to fetch data from API
def get_data_from_api(api_url, api_params):
    try:
        # Call API with the base URL and params
        response = requests.get(api_url, params=api_params)
        # Print the final URL
        print(f"Final URL: {response.url}")
        # Printe the API respose
        print(f"API Response Code: {response.status_code}")
        response.raise_for_status()
        return response.json()

    # Handle errors
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except requests.exceptions.ConnectionError as conn_err:
        print(f"Connection error occurred: {conn_err}")
    except requests.exceptions.Timeout as timeout_err:
        print(f"Timeout error occurred: {timeout_err}")
    except requests.exceptions.RequestException as req_err:
        print(f"An error occurred: {req_err}")
    return None

# %%
def save_json_to_minio(minio_endpoint, access_key, secret_key, bucket_name, object_name, json_data):
    try:
        # Create Minio client
        minio_client = Minio(minio_endpoint, access_key=access_key, secret_key=secret_key, secure=False)

        # Check if the bucket already exists
        if not minio_client.bucket_exists(bucket_name):
            # If not, create the bucket
            minio_client.make_bucket(bucket_name)

        # Convert the json_data to a string and then to bytes
        json_string = json.dumps(json_data)
        json_bytes = json_string.encode('utf-8')

        # Convert bytes to a byte stream
        byte_stream = BytesIO(json_bytes)

        # Save the json_data to the MinIO bucket
        minio_client.put_object(bucket_name, object_name, byte_stream, length=len(json_bytes), content_type='application/json')

        print(f"'{object_name}' is successfully uploaded to bucket '{bucket_name}'.")

    except Exception as e:
        print(f"An error occurred while saving JSON to MinIO: {e}")
    return None

# %%
# Fetch data from API
json_data = get_data_from_api(api_url, api_params)
# Out:
# Final URL: https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?q=allowedVehicleType%3D%3DtwoWheeledVehicle&type=OnStreetParking&limit=1000
# API Response Code: 200

# %%
# Save the JSON data to MinIO
save_json_to_minio(minio_endpoint, access_key, secret_key, bucket_name, object_name, json_data)
# Out:
# 'twowheel/twowheel20240606225259.json' is successfully uploaded to bucket 'raw'.

# %% [markdown]
# # 2. Read JSON from bucket and preprocess (PANDAS)

# %%
def read_json_from_minio(minio_endpoint, access_key, secret_key, bucket_name, object_name):
    try:
        # Create Minio client
        minio_client = Minio(minio_endpoint, access_key=access_key, secret_key=secret_key, secure=False)

        # Read the JSON data from the MinIO bucket
        json_data = minio_client.get_object(bucket_name, object_name)

        # Read the content of the file-like object and decode JSON
        json_content = json_data.read().decode('utf-8')

        # Parse the JSON content
        json_parsed = json.loads(json_content)

        return json_parsed
    except Exception as e:
        print(f"An error occurred while reading JSON from MinIO: {e}")
        return None

# %%
# Create dataframe from JSON, use get for the keys so that it doesn't break if they don't exist
def create_dataframe_from_json(json_data):
    try:
        extracted_data = []

        for json_obj in json_data:
            extracted_info = {
                'id': json_obj.get('id'),
                'street_address': json_obj['address']['value'].get('streetAddress'),
                'allowed_vehicle_type': json_obj.get('allowedVehicleType', {}).get('value', [None])[0],
                'available_spot_number': json_obj.get('availableSpotNumber', {}).get('value'),
                'data_provider': json_obj.get('dataProvider', {}).get('value'),
                'description': json_obj.get('description', {}).get('value'),
                'latitude': json_obj['location']['value'].get('coordinates', [None, None])[1],
                'longitude': json_obj['location']['value'].get('coordinates', [None, None])[0],
                'occupied_spot_number': json_obj.get('occupiedSpotNumber', {}).get('value'),
                'total_spot_number': json_obj.get('totalSpotNumber', {}).get('value')
            }
            extracted_data.append(extracted_info)

        df = pd.DataFrame(extracted_data)
        return df
    except Exception as e:
        print(f"An error occurred while creating the dataframe: {e}")
        return None

# %% [markdown]
# ## 2.1a Read single JSON

# %%
# Define the bucket name and object name
bucket_name = "raw"
object_name = "twowheel/twowheel20240604221915.json"

# %%
# Open JSON from Bucket
json_data = read_json_from_minio(minio_endpoint, access_key, secret_key, bucket_name, object_name)
# Out:
# An error occurred while reading JSON from MinIO: S3 operation failed; code: NoSuchKey, message: The specified key does not exist., resource: /raw/twowheel/twowheel_20240604221915.json, request_id: 17D68B2EC0FAC9F4, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8, bucket_name: raw, object_name: twowheel/twowheel_20240604221915.json

# %%
# create dataframe:
df_raw = create_dataframe_from_json(json_data)

# %%
df_raw
# Out:
# 222

# %% [markdown]
# ## 2.1b Read and concatenate JSON files from MinIO

# %%
def read_bucket_json_df_concatenate(minio_endpoint, access_key, secret_key, bucket_name):
    try:
        # Create Minio client
        minio_client = Minio(minio_endpoint, access_key=access_key, secret_key=secret_key, secure=False)

        # List all objects in the bucket
        objects = minio_client.list_objects(bucket_name, recursive=True)

        # Get a glob of folder
        file_list = {obj.object_name[-19:-5]: obj.object_name for obj in objects}

        df_list = []

        for date, object_name in file_list.items():
            try:
                # Read the JSON data from MinIO
                json_data = read_json_from_minio(minio_endpoint, access_key, secret_key, bucket_name, object_name)

                # Create a dataframe from the JSON data
                df = create_dataframe_from_json(json_data)
                df["date"] = pd.to_datetime(date, format='%Y%m%d%H%M%S')

                df_list.append(df)
            except Exception as e:
                print(f"An error occurred while processing object '{object_name}': {e}")

        return pd.concat(df_list, ignore_index=True)

    except Exception as e:
        print(f"An error occurred while reading bucket '{bucket_name}': {e}")
        return None

# %%
# Concatenate the dataframes
final_df_raw = read_bucket_json_df_concatenate(minio_endpoint, access_key, secret_key, bucket_name)

# %%
final_df_raw
# Out:
#                                                      id  \
# 0     urn:ngsi-ld:OnStreetParking:porto:cmp:7cfee26e...
# 1     urn:ngsi-ld:OnStreetParking:porto:cmp:a7c593b1...
# 2     urn:ngsi-ld:OnStreetParking:porto:cmp:2a64f748...
# 3     urn:ngsi-ld:OnStreetParking:porto:cmp:37f0cf74...
# 4     urn:ngsi-ld:OnStreetParking:porto:cmp:e4a90d10...
# ...                                                 ...
# 1771  urn:ngsi-ld:OnStreetParking:porto:cmp:5d4b6ef9...
# 1772  urn:ngsi-ld:OnStreetParking:porto:cmp:b8d167eb...
# 1773  urn:ngsi-ld:OnStreetParking:porto:cmp:fa3f8cb7...
# 1774  urn:ngsi-ld:OnStreetParking:porto:cmp:41374df4...
# 1775  urn:ngsi-ld:OnStreetParking:porto:cmp:d27f8439...
#
#                           street_address allowed_vehicle_type  \
# 0          Pc Mouzinho De Albuquerque 56    twoWheeledVehicle
# 1                Passeio Das Virtudes 12    twoWheeledVehicle
# 2             Cpo Martires Da Patria 174    twoWheeledVehicle
# 3              Rua de Sá da Bandeira 637    twoWheeledVehicle
# 4                   R D João Coutinho 30    twoWheeledVehicle
# ...                                  ...                  ...
# 1771                     Lg Alfandega 22    twoWheeledVehicle
# 1772          R Mouzinho Da Silveira 171    twoWheeledVehicle
# 1773  Rua do Clube dos Fenianos 4000-407    twoWheeledVehicle
# 1774                 R Inf D Henrique 36    twoWheeledVehicle
# 1775                   Tv Nova Sintra 55    twoWheeledVehicle
#
#       available_spot_number data_provider                        description  \
# 0                        10           cmp   Praça de Mouzinho de Albuquerque
# 1                         5           cmp               Passeio das Virtudes
# 2                        -3           cmp       Campo dos Mártires da Pátria
# 3                         4           cmp                    Pátio do Bolhão
# 4                         7           cmp    Rua do Engenheiro Ferreira Dias
# ...                     ...           ...                                ...
# 1771                     23           cmp                 Largo da Alfândega
# 1772                      6           cmp        Rua de Mouzinho da Silveira
# 1773                     15           cmp  Praça do General Humberto Delgado
# 1774                     10           cmp         Rua do Infante D. Henrique
# 1775                      9           cmp        Rua do Barão de Nova Sintra
#
#        latitude  longitude  occupied_spot_number  total_spot_number  \
# 0     41.158887  -8.628684                     0                 10
# 1     41.144293  -8.618336                     5                 10
# 2     41.145245  -8.617373                    13                 10
# 3     41.151680  -8.606654                     6                 10
# 4     41.177007  -8.648385                     3                 10
# ...         ...        ...                   ...                ...
# 1771  41.143987  -8.621967                     7                 30
# 1772  41.143726  -8.612946                     4                 10
# 1773  41.149670  -8.611032                     5                 20
# 1774  41.141235  -8.614237                     6                 16
# 1775  41.145090  -8.590482                     0                  9
#
#                     date
# 0    2024-05-31 20:58:09
# 1    2024-05-31 20:58:09
# 2    2024-05-31 20:58:09
# 3    2024-05-31 20:58:09
# 4    2024-05-31 20:58:09
# ...                  ...
# 1771 2024-06-07 21:10:02
# 1772 2024-06-07 21:10:02
# 1773 2024-06-07 21:10:02
# 1774 2024-06-07 21:10:02
# 1775 2024-06-07 21:10:02
#
# [1776 rows x 11 columns]

# %%
final_df_raw.describe()
# Out:
#        available_spot_number     latitude    longitude  occupied_spot_number  \
# count            1776.000000  1776.000000  1776.000000           1776.000000
# mean                7.073198    41.158596    -8.626108              3.625000
# min               -35.000000    41.140887    -8.688397              0.000000
# 25%                 5.750000    41.149379    -8.646125              1.000000
# 50%                 8.000000    41.157308    -8.620489              2.000000
# 75%                10.000000    41.165495    -8.606391              5.000000
# max                24.000000    41.178858    -8.574214             45.000000
# std                 4.461067     0.010367     0.027123              4.488122
#
#        total_spot_number                        date
# count        1776.000000                        1776
# mean           10.698198         2024-06-04 08:44:27
# min             9.000000         2024-05-31 20:58:09
# 25%            10.000000  2024-06-02 15:00:53.500000
# 50%            10.000000  2024-06-04 10:10:29.500000
# 75%            10.000000  2024-06-06 02:43:15.500000
# max            30.000000         2024-06-07 21:10:02
# std             2.667513                         NaN

# %% [markdown]
# ## 2.2 Geocode and preprocess data

# %%
# Helper function to geocode and extract post code from lat lon using Geopy Nominatim
def get_postcode_info_latlon(lat, lon):
    geolocator = Nominatim(user_agent="get_location")
    geocode = RateLimiter(geolocator.reverse, min_delay_seconds=1)
    try:
        location = geocode(f"{lat}, {lon}",exactly_one=True)
        address = location.raw.get('address', {})
        post_code = address.get('postcode', '')
        return pd.Series([post_code])
    except Exception as e:
        return pd.Series([''])

# %%
def complete_geocode_table(df):
    # Isolate and get unique lat/lon combinations
    df = df[["latitude", "longitude", "total_spot_number"]].groupby(["latitude", "longitude"]).first().reset_index()
    # get post code from APIO
    df["postal_code"] = df.apply(lambda x: get_postcode_info_latlon(x["latitude"], x["longitude"]), axis=1)
    # Convert to the format in the source table
    df["postal_code"] = df["postal_code"].str.replace("-","").astype(int)
    #Get source table
    df_match_postcode=pd.read_csv(match_postcode_url,encoding='utf-8')
    #Cleanup and rename
    to_geocode = df.merge(df_match_postcode[['CodigoPostal', 'Concelho', 'Freguesia Final (Pós RATF)']], left_on="postal_code", right_on='CodigoPostal', how="left")
    to_geocode = to_geocode.drop(columns=["CodigoPostal"]).rename(columns={"Concelho": "concelho", "Freguesia Final (Pós RATF)": "freguesia"})
    return to_geocode

# %%
def process_geocode_data(df_raw, to_geocode):
    try:
        # Calculate occupied spots percentage
        df_raw["occupied_perc"] = df_raw["occupied_spot_number"] / df_raw["total_spot_number"] * 100

        # Convert date to datetime and set as index
        df_raw['date'] = pd.to_datetime(df_raw['date'])
        df_raw.set_index('date', inplace=True)

        # Define the window size
        window_size = 2

        # Apply rolling calculations
        df_processed = df_raw.groupby(['id', 'street_address', 'latitude', 'longitude']).apply(
            lambda x: x.rolling(window=window_size, min_periods=1).agg({
                'occupied_spot_number': ['mean', 'max', 'min'],
                'occupied_perc': ['mean', 'max', 'min']
            })
        ).reset_index()

        # Flatten the multi-level columns
        df_processed.columns = ['id', 'street_address', 'latitude', 'longitude', 'date',
                                   'occupied_spot_number_mean', 'occupied_spot_number_max', 'occupied_spot_number_min',
                                   'occupied_perc_mean', 'occupied_perc_max', 'occupied_perc_min']

        # Add Freguesia and concelho
        df_processed = df_processed.merge(to_geocode[["latitude","longitude","concelho","freguesia", "total_spot_number"]], on=["latitude","longitude"], how="left")

        return df_processed

    except Exception as e:
        print(f"An error occurred while processing the data: {e}")
        return None

# %%
to_geocode = complete_geocode_table(final_df_raw)

# %%
to_geocode
# Out:
#       latitude  longitude  total_spot_number  postal_code           concelho  \
# 0    41.140887  -8.617493                 20      4050492              Porto
# 1    41.141235  -8.614237                 16      4050029              Porto
# 2    41.141871  -8.604642                 10      4000279              Porto
# 3    41.142254  -8.615234                 20      4050116              Porto
# 4    41.142632  -8.608252                 10      4000279              Porto
# ..         ...        ...                ...          ...                ...
# 217  41.177946  -8.609206                 10      4200491              Porto
# 218  41.178148  -8.606578                 10      4200135              Porto
# 219  41.178485  -8.586920                 10      4200601              Porto
# 220  41.178844  -8.600135                 20      4400319  Vila Nova de Gaia
# 221  41.178858  -8.634478                 10      4250043              Porto
#
#                                              freguesia
# 0    União das freguesias de Cedofeita, Santo Ildef...
# 1    União das freguesias de Cedofeita, Santo Ildef...
# 2    União das freguesias de Cedofeita, Santo Ildef...
# 3    União das freguesias de Cedofeita, Santo Ildef...
# 4    União das freguesias de Cedofeita, Santo Ildef...
# ..                                                 ...
# 217                                           Paranhos
# 218                                           Paranhos
# 219                                           Paranhos
# 220  União das freguesias de Santa Marinha e São Pe...
# 221                                            Ramalde
#
# [222 rows x 6 columns]

# %%
to_geocode[to_geocode.freguesia.isnull()]
# Out:
#       latitude  longitude  total_spot_number  postal_code concelho freguesia
# 95   41.155089  -8.618470                 10         4050      NaN       NaN
# 150  41.162704  -8.611365                 10      4200167      NaN       NaN
# 195  41.174638  -8.598940                 10      4200298      NaN       NaN
# 208  41.176995  -8.596201                 10      4200298      NaN       NaN
# 210  41.177056  -8.594558                 10      4200298      NaN       NaN
# 216  41.177601  -8.597936                 20      4200298      NaN       NaN

# %%
# Manual corrections
to_geocode.at[95, "concelho"] = "Porto"
to_geocode.at[95, "freguesia"] = "União das Freguesias de Cedofeita, Santo Ildefonso, Sé, Miragaia, São Nicolau e Vitória"
to_geocode.at[150, "concelho"] = "Porto"
to_geocode.at[150, "freguesia"] = "União das Freguesias de Cedofeita, Santo Ildefonso, Sé, Miragaia, São Nicolau e Vitória"
to_geocode.at[195, "concelho"] = "Porto"
to_geocode.at[195, "freguesia"] = "Paranhos"
to_geocode.at[208, "concelho"] = "Porto"
to_geocode.at[208, "freguesia"] = "Paranhos"
to_geocode.at[210, "concelho"] = "Porto"
to_geocode.at[210, "freguesia"] = "Paranhos"
to_geocode.at[216, "concelho"] = "Porto"
to_geocode.at[216, "freguesia"] = "Paranhos"

# %%
to_geocode[to_geocode.freguesia.isnull()]
# Out:
# Empty DataFrame
# Columns: [latitude, longitude, total_spot_number, postal_code, concelho, freguesia]
# Index: []

# %%
df_processed = process_geocode_data(final_df_raw, to_geocode)
# Out:
# /tmp/ipykernel_17728/1579727939.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_processed = df_raw.groupby(['id', 'street_address', 'latitude', 'longitude']).apply(

# %%
df_processed.head(2)
# Out:
#                                                   id  \
# 0  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 1  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
#
#                 street_address   latitude  longitude                date  \
# 0  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 1  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
#
#    occupied_spot_number_mean  occupied_spot_number_max  \
# 0                        3.0                       3.0
# 1                        2.5                       3.0
#
#    occupied_spot_number_min  occupied_perc_mean  occupied_perc_max  \
# 0                       3.0                30.0               30.0
# 1                       2.0                25.0               30.0
#
#    occupied_perc_min concelho freguesia  total_spot_number
# 0               30.0    Porto   Ramalde                 10
# 1               20.0    Porto   Ramalde                 10

# %%
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1776 entries, 0 to 1775
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1776 non-null   object
#  1   street_address             1776 non-null   object
#  2   latitude                   1776 non-null   float64
#  3   longitude                  1776 non-null   float64
#  4   date                       1776 non-null   datetime64[ns]
#  5   occupied_spot_number_mean  1776 non-null   float64
#  6   occupied_spot_number_max   1776 non-null   float64
#  7   occupied_spot_number_min   1776 non-null   float64
#  8   occupied_perc_mean         1776 non-null   float64
#  9   occupied_perc_max          1776 non-null   float64
#  10  occupied_perc_min          1776 non-null   float64
#  11  concelho                   1776 non-null   object
#  12  freguesia                  1776 non-null   object
#  13  total_spot_number          1776 non-null   int64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(4)
# memory usage: 194.4+ KB

# %%
# Save dataframe to csv -> Just for PowerBI prototype purposes
df_processed.drop(columns=["id"]).to_csv("twowheel20240601.csv", index=False, encoding='utf-16')

# %% [markdown]
# ## 2.3. Save preprocessed table to bucket

# %%
def save_parquet_to_minio(df, minio_endpoint, access_key, secret_key, bucket_name, parquet_output_path = f"2wheel_{date}.parquet", object_name = f"twowheel/2wheel_{date}.parquet", secure=False):
    try:
        # Create Minio client
        minio_client = Minio(minio_endpoint, access_key=access_key, secret_key=secret_key, secure=secure)

        # Create a dynamic file name including the current date and time
        date = datetime.today().strftime('%Y%m%d%H%M%S')
        parquet_output_path = parquet_output_path
        object_name = object_name

        # Save the preprocessed DataFrame as Parquet file
        df.to_parquet(parquet_output_path)

        # Upload the Parquet file to MinIO
        minio_client.fput_object(bucket_name, object_name, parquet_output_path)
        print(f"Preprocessed data is saved as Parquet in the MinIO bucket: {bucket_name}/{object_name}")

        # Remove the local Parquet file after upload
        if os.path.exists(parquet_output_path):
            os.remove(parquet_output_path)
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
save_parquet_to_minio(df_processed, minio_endpoint, access_key, secret_key, output_bucket_name)
# Out:
# Preprocessed data is saved as Parquet in the MinIO bucket: preprocessed/twowheel/2wheel_20240610230610.parquet

# %% [markdown]
# # 3- Read and send preprocessed to Postgres database

# %%
# PostgreSQL connection details
host = 'localhost'
port = 5432
database = 'data_warehouse'
user = 'postgres'
password = 'password123'

# Preprocess table to use
input_bucket_name = "preprocessed"
#input_object_name = "twowheel/2wheel_20240608093101.parquet"
input_object_name = "twowheel/2wheel_20240614185451.parquet"

# %%
# Read Parquet file into memory

def read_parquet_from_minio(minio_endpoint, access_key, secret_key, bucket_name, object_name):
    try:
        # Create Minio client
        minio_client = Minio(minio_endpoint, access_key=access_key, secret_key=secret_key, secure=False)

        # Get the Parquet file from MinIO as a stream
        response = minio_client.get_object(bucket_name, object_name)

        # Read the Parquet file into a Pandas DataFrame directly from the stream
        data = response.read()
        df = pd.read_parquet(BytesIO(data))

        # Close the response
        response.close()
        response.release_conn()

        return df
    except Exception as e:
        print(f"An error occurred while reading Parquet from MinIO: {e}")
        return None

# %%
def connect_to_postgresql(host, port, database, user, password, schema):
    # Define the database URL
    db_url = f'postgresql://{user}:{password}@{host}:{port}/{database}'

    try:
        # Create the SQLAlchemy engine with the specified schema
        engine = create_engine(db_url, connect_args={"options": f"-csearch_path={schema}"})

        # Print success message
        print("Connected to PostgreSQL successfully!")

        # Return the engine object
        return engine

    except Exception as e:
        print(f"An error occurred while connecting to PostgreSQL: {e}")
        return None

# %%
df_processed = read_parquet_from_minio(minio_endpoint, access_key, secret_key, input_bucket_name, input_object_name)

# %%
df_processed.head()
# Out:
#                                                   id  \
# 0  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 1  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 2  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 3  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 4  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
#
#                 street_address   latitude  longitude                date  \
# 0  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 1  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
# 2  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-02 23:45:04
# 3  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-03 22:01:44
# 4  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-04 22:19:15
#
#    occupied_spot_number_mean  occupied_spot_number_max  \
# 0                        3.0                       3.0
# 1                        2.5                       3.0
# 2                        2.5                       3.0
# 3                        3.0                       3.0
# 4                        5.0                       7.0
#
#    occupied_spot_number_min  occupied_perc_mean  occupied_perc_max  \
# 0                       3.0                30.0               30.0
# 1                       2.0                25.0               30.0
# 2                       2.0                25.0               30.0
# 3                       3.0                30.0               30.0
# 4                       3.0                50.0               70.0
#
#    occupied_perc_min concelho freguesia  total_spot_number
# 0               30.0    Porto   Ramalde                 10
# 1               20.0    Porto   Ramalde                 10
# 2               20.0    Porto   Ramalde                 10
# 3               30.0    Porto   Ramalde                 10
# 4               30.0    Porto   Ramalde                 10

# %%
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1776 entries, 0 to 1775
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1776 non-null   object
#  1   street_address             1776 non-null   object
#  2   latitude                   1776 non-null   float64
#  3   longitude                  1776 non-null   float64
#  4   date                       1776 non-null   datetime64[ns]
#  5   occupied_spot_number_mean  1776 non-null   float64
#  6   occupied_spot_number_max   1776 non-null   float64
#  7   occupied_spot_number_min   1776 non-null   float64
#  8   occupied_perc_mean         1776 non-null   float64
#  9   occupied_perc_max          1776 non-null   float64
#  10  occupied_perc_min          1776 non-null   float64
#  11  concelho                   1776 non-null   object
#  12  freguesia                  1776 non-null   object
# dtypes: datetime64[ns](1), float64(8), object(4)
# memory usage: 180.5+ KB

# %%
conn = connect_to_postgresql(host, port, database, user, password)
# Out:
# Connected to PostgreSQL successfully!

# %%
# Define the table name
table_name = 'preprocessed_data'

# Send the preprocessed DataFrame to SQL
df_processed.to_sql(table_name, conn, if_exists='replace', index=False)

# Close the connection
conn.close()

print("Preprocessed data is sent to SQL successfully!")
# Out:
# Preprocessed data is sent to SQL successfully!

# %% [markdown]
# ## 3.2 Final version

# %% [markdown]
# ### 3.2.1 Upload INE table to bucket as parquet

# %%
input_bucket_name = "preprocessed"

# %%
ine = pd.read_csv("ine.csv", encoding='utf-16')

# %%
ine.head()
# Out:
#                                            freguesia genero  faixa_etaria  \
# 0                                          Revinhade      M  30 - 39 anos
# 1                                              Idães      M  30 - 39 anos
# 2  União das freguesias de Margaride (Santa Eulál...      M  30 - 39 anos
# 3  União das freguesias de Pedreira, Rande e Sern...      M  30 - 39 anos
# 4  União das freguesias de Vila Cova da Lixa e Bo...      M  30 - 39 anos
#
#    count    concelho   ano
# 0     55  Felgueiras  2021
# 1    162  Felgueiras  2021
# 2   1169  Felgueiras  2021
# 3    212  Felgueiras  2021
# 4    400  Felgueiras  2021

# %%
# Remove ano as it is always the same
ine = ine.drop(columns=["ano"])

# %%
save_parquet_to_minio(ine, minio_endpoint, access_key, secret_key, input_bucket_name, parquet_output_path = f"ine_{date}.parquet", object_name = f"ine/ine_{date}.parquet")
# Out:
# Preprocessed data is saved as Parquet in the MinIO bucket: preprocessed/ine/ine_20240610213356.parquet

# %% [markdown]
# ## 3.2.2 Feed the SQL database with the twowheel data and the INE data

# %%
# PostgreSQL connection details
host = 'localhost'
port = 5432
database = 'datawarehouse'
schema='testschema'
user = 'postgres'
password = 'password123'

# Load current files
object_name_2wheel = "twowheel/2wheel_20240610230610.parquet"
object_name_ine = "ine/ine_20240610213356.parquet"

# %%
# Read the 2 wheel Parquet file from MinIO
data = read_parquet_from_minio(minio_endpoint, access_key, secret_key, input_bucket_name, object_name_2wheel)

# %%
data.head(2)
# Out:
#                                                   id  \
# 0  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 1  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
#
#                 street_address   latitude  longitude                date  \
# 0  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 1  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
#
#    occupied_spot_number_mean  occupied_spot_number_max  \
# 0                        3.0                       3.0
# 1                        2.5                       3.0
#
#    occupied_spot_number_min  occupied_perc_mean  occupied_perc_max  \
# 0                       3.0                30.0               30.0
# 1                       2.0                25.0               30.0
#
#    occupied_perc_min concelho freguesia  total_spot_number
# 0               30.0    Porto   Ramalde                 10
# 1               20.0    Porto   Ramalde                 10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1776 entries, 0 to 1775
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1776 non-null   object
#  1   street_address             1776 non-null   object
#  2   latitude                   1776 non-null   float64
#  3   longitude                  1776 non-null   float64
#  4   date                       1776 non-null   datetime64[ns]
#  5   occupied_spot_number_mean  1776 non-null   float64
#  6   occupied_spot_number_max   1776 non-null   float64
#  7   occupied_spot_number_min   1776 non-null   float64
#  8   occupied_perc_mean         1776 non-null   float64
#  9   occupied_perc_max          1776 non-null   float64
#  10  occupied_perc_min          1776 non-null   float64
#  11  concelho                   1776 non-null   object
#  12  freguesia                  1776 non-null   object
#  13  total_spot_number          1776 non-null   int64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(4)
# memory usage: 194.4+ KB

# %%
data.columns
# Out:
# Index(['id', 'street_address', 'latitude', 'longitude', 'date',
#        'occupied_spot_number_mean', 'occupied_spot_number_max',
#        'occupied_spot_number_min', 'occupied_perc_mean', 'occupied_perc_max',
#        'occupied_perc_min', 'concelho', 'freguesia', 'total_spot_number'],
#       dtype='object')

# %%
# Load the population parquet
population_data = read_parquet_from_minio(minio_endpoint, access_key, secret_key, input_bucket_name, object_name_ine)c

# %%
population_data.head(2)
# Out:
#    freguesia genero  faixa_etaria  count    concelho
# 0  Revinhade      M  30 - 39 anos     55  Felgueiras
# 1      Idães      M  30 - 39 anos    162  Felgueiras

# %%
population_data.columns
# Out:
# Index(['freguesia', 'genero', 'faixa_etaria', 'count', 'concelho'], dtype='object')

# %%
# Simplify and try only fact and dim location
if data is not None:
    # Ensure all column names are lowercase
    data.columns = map(str.lower, data.columns)

    # Establish connection to the PostgreSQL database
    engine = connect_to_postgresql(host, port, database, user, password, schema)

    if engine is not None:
        metadata = MetaData(schema=schema)
        try:
            metadata.reflect(bind=engine)

            # Access the required tables
            dim_location = Table('dimlocation', metadata, autoload_with=engine, schema=schema)
            fact_two_wheel = Table('facttwowheel', metadata, autoload_with=engine, schema=schema)

            with engine.connect() as connection:
                # Insert unique locations into DimLocation with conflict resolution
                unique_locations = data[['latitude', 'longitude', 'concelho', 'freguesia']].drop_duplicates()
                location_inserts = unique_locations.to_dict(orient='records')
                print("Inserting into dimlocation:", location_inserts)  # Log insert data for debugging
                insert_statement = pg_insert(dim_location).values(location_inserts)
                upsert_statement = insert_statement.on_conflict_do_nothing(index_elements=['latitude', 'longitude'])
                connection.execute(upsert_statement)
                connection.commit()  # Commit the transaction to ensure data is saved

                # Verify data exists before insertion
                if not data.empty:
                    # Log the data being inserted into FactTwoWheel
                    print("Inserting data into FactTwoWheel:")
                    print(data.head())

                    # Insert data into FactTwoWheel
                    fact_inserts = []
                    for index, row in data.iterrows():
                        fact_inserts.append({
                            'date': row['date'].date(),  # Directly use the date part of the Timestamp
                            'latitude': row['latitude'],
                            'longitude': row['longitude'],
                            'meanoccupation': row['occupied_spot_number_mean'],
                            'percentoccupation': row['occupied_perc_mean'],
                            'minoccupation': row['occupied_spot_number_min'],
                            'maxoccupation': row['occupied_spot_number_max'],
                            'totalspotnumber': row['total_spot_number']
                        })
                    try:
                        connection.execute(pg_insert(fact_two_wheel).on_conflict_do_nothing(), fact_inserts)
                        connection.commit()  # Commit the transaction to ensure data is saved
                    except SQLAlchemyError as e:
                        print(f"An error occurred during fact_two_wheel insertion: {e}")
                else:
                    print("No data to insert into FactTwoWheel.")

            print("Two-wheel data insertion completed successfully!")

        except KeyError as e:
            print(f"Column not found in the DataFrame: {e}")
        except SQLAlchemyError as e:
            print(f"An error occurred with SQLAlchemy: {e}")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")

# %% [markdown]
# ### Attempt 2 Merge data tables and then populate

# %%
# PostgreSQL connection details
host = 'localhost'
port = 5432
database = 'datawarehouse'
schema='testschema1'
user = 'postgres'
password = 'password123'

# Load current files
object_name_2wheel = "twowheel/2wheel_20240610230610.parquet"
object_name_ine = "ine/ine_20240610213356.parquet"

# %%
# Read the 2 wheel Parquet file from MinIO
data = read_parquet_from_minio(minio_endpoint, access_key, secret_key, input_bucket_name, object_name_2wheel)

# %%
# Load the population parquet
population_data = read_parquet_from_minio(minio_endpoint, access_key, secret_key, input_bucket_name, object_name_ine)

# %%
# Merge tables on freguesia
full_table = pd.merge(data, population_data, on=["concelho", "freguesia"])
# Create a unique location_id for each combination of latitude and longitude
full_table['locationID'] = full_table.groupby(['latitude', 'longitude']).ngroup() + 1

# %%
full_table.head(30)
# Out:
#                                                    id  \
# 0   urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 1   urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 2   urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 3   urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 4   urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 5   urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 6   urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 7   urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 8   urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 9   urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 10  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 11  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 12  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 13  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 14  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 15  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 16  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 17  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 18  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 19  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 20  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 21  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 22  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 23  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 24  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 25  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 26  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 27  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 28  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 29  urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
#
#                  street_address   latitude  longitude                date  \
# 0   Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 1   Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 2   Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 3   Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 4   Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 5   Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 6   Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 7   Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 8   Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 9   Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 10  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 11  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 12  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 13  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 14  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 15  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 16  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 17  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 18  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 19  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 20  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 21  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 22  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
# 23  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
# 24  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
# 25  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
# 26  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
# 27  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
# 28  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
# 29  Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
#
#     occupied_spot_number_mean  occupied_spot_number_max  \
# 0                         3.0                       3.0
# 1                         3.0                       3.0
# 2                         3.0                       3.0
# 3                         3.0                       3.0
# 4                         3.0                       3.0
# 5                         3.0                       3.0
# 6                         3.0                       3.0
# 7                         3.0                       3.0
# 8                         3.0                       3.0
# 9                         3.0                       3.0
# 10                        3.0                       3.0
# 11                        3.0                       3.0
# 12                        3.0                       3.0
# 13                        3.0                       3.0
# 14                        3.0                       3.0
# 15                        3.0                       3.0
# 16                        3.0                       3.0
# 17                        3.0                       3.0
# 18                        3.0                       3.0
# 19                        3.0                       3.0
# 20                        3.0                       3.0
# 21                        3.0                       3.0
# 22                        2.5                       3.0
# 23                        2.5                       3.0
# 24                        2.5                       3.0
# 25                        2.5                       3.0
# 26                        2.5                       3.0
# 27                        2.5                       3.0
# 28                        2.5                       3.0
# 29                        2.5                       3.0
#
#     occupied_spot_number_min  occupied_perc_mean  occupied_perc_max  \
# 0                        3.0                30.0               30.0
# 1                        3.0                30.0               30.0
# 2                        3.0                30.0               30.0
# 3                        3.0                30.0               30.0
# 4                        3.0                30.0               30.0
# 5                        3.0                30.0               30.0
# 6                        3.0                30.0               30.0
# 7                        3.0                30.0               30.0
# 8                        3.0                30.0               30.0
# 9                        3.0                30.0               30.0
# 10                       3.0                30.0               30.0
# 11                       3.0                30.0               30.0
# 12                       3.0                30.0               30.0
# 13                       3.0                30.0               30.0
# 14                       3.0                30.0               30.0
# 15                       3.0                30.0               30.0
# 16                       3.0                30.0               30.0
# 17                       3.0                30.0               30.0
# 18                       3.0                30.0               30.0
# 19                       3.0                30.0               30.0
# 20                       3.0                30.0               30.0
# 21                       3.0                30.0               30.0
# 22                       2.0                25.0               30.0
# 23                       2.0                25.0               30.0
# 24                       2.0                25.0               30.0
# 25                       2.0                25.0               30.0
# 26                       2.0                25.0               30.0
# 27                       2.0                25.0               30.0
# 28                       2.0                25.0               30.0
# 29                       2.0                25.0               30.0
#
#     occupied_perc_min concelho freguesia  total_spot_number genero  \
# 0                30.0    Porto   Ramalde                 10      M
# 1                30.0    Porto   Ramalde                 10      H
# 2                30.0    Porto   Ramalde                 10      M
# 3                30.0    Porto   Ramalde                 10      H
# 4                30.0    Porto   Ramalde                 10      M
# 5                30.0    Porto   Ramalde                 10      H
# 6                30.0    Porto   Ramalde                 10      M
# 7                30.0    Porto   Ramalde                 10      H
# 8                30.0    Porto   Ramalde                 10      M
# 9                30.0    Porto   Ramalde                 10      H
# 10               30.0    Porto   Ramalde                 10      M
# 11               30.0    Porto   Ramalde                 10      H
# 12               30.0    Porto   Ramalde                 10      M
# 13               30.0    Porto   Ramalde                 10      H
# 14               30.0    Porto   Ramalde                 10      M
# 15               30.0    Porto   Ramalde                 10      H
# 16               30.0    Porto   Ramalde                 10      M
# 17               30.0    Porto   Ramalde                 10      H
# 18               30.0    Porto   Ramalde                 10      M
# 19               30.0    Porto   Ramalde                 10      H
# 20               30.0    Porto   Ramalde                 10      M
# 21               30.0    Porto   Ramalde                 10      H
# 22               20.0    Porto   Ramalde                 10      M
# 23               20.0    Porto   Ramalde                 10      H
# 24               20.0    Porto   Ramalde                 10      M
# 25               20.0    Porto   Ramalde                 10      H
# 26               20.0    Porto   Ramalde                 10      M
# 27               20.0    Porto   Ramalde                 10      H
# 28               20.0    Porto   Ramalde                 10      M
# 29               20.0    Porto   Ramalde                 10      H
#
#         faixa_etaria  count  locationid
# 0       30 - 39 anos   2378         176
# 1       30 - 39 anos   2278         176
# 2       90 - 99 anos    420         176
# 3       90 - 99 anos    146         176
# 4       10 - 19 anos   1884         176
# 5       10 - 19 anos   1872         176
# 6       20 - 29 anos   2127         176
# 7       20 - 29 anos   2167         176
# 8       60 - 69 anos   2937         176
# 9       60 - 69 anos   2103         176
# 10        0 - 9 anos   1596         176
# 11        0 - 9 anos   1661         176
# 12      70 - 79 anos   2258         176
# 13      70 - 79 anos   1666         176
# 14      50 - 59 anos   3079         176
# 15      50 - 59 anos   2491         176
# 16      80 - 89 anos   1432         176
# 17      80 - 89 anos    765         176
# 18  100 ou mais anos     15         176
# 19  100 ou mais anos      4         176
# 20      40 - 49 anos   2968         176
# 21      40 - 49 anos   2600         176
# 22      30 - 39 anos   2378         176
# 23      30 - 39 anos   2278         176
# 24      90 - 99 anos    420         176
# 25      90 - 99 anos    146         176
# 26      10 - 19 anos   1884         176
# 27      10 - 19 anos   1872         176
# 28      20 - 29 anos   2127         176
# 29      20 - 29 anos   2167         176

# %%
def insert_data_to_db(merged_data, host, port, database, user, password, schema):
    if merged_data is not None:
        # Ensure all column names are lowercase
        merged_data.columns = map(str.lower, merged_data.columns)

        # Establish connection to the PostgreSQL database
        engine = connect_to_postgresql(host, port, database, user, password, schema)

        if engine is not None:
            metadata = MetaData(schema=schema)
            try:
                metadata.reflect(bind=engine)

                # Access the required tables
                dim_location = Table('dimlocation', metadata, autoload_with=engine, schema=schema)
                fact_two_wheel = Table('facttwowheel', metadata, autoload_with=engine, schema=schema)
                dim_population = Table('dimpopulation', metadata, autoload_with=engine, schema=schema)

                with engine.connect() as connection:
                    # Insert unique locations into DimLocation with conflict resolution
                    unique_locations = merged_data[['locationid', 'latitude', 'longitude', 'concelho', 'freguesia']].drop_duplicates()
                    location_inserts = unique_locations.to_dict(orient='records')
                    print("Inserting into dimlocation:", location_inserts)  # Log insert data for debugging
                    insert_statement = pg_insert(dim_location).values(location_inserts)
                    upsert_statement = insert_statement.on_conflict_do_nothing(index_elements=['latitude', 'longitude'])
                    connection.execute(upsert_statement)
                    connection.commit()  # Commit the transaction to ensure data is saved

                    # Verify data exists before insertion
                    if not merged_data.empty:
                        # Log the data being inserted into FactTwoWheel
                        print("Inserting data into FactTwoWheel:")
                        print(merged_data.head())

                        # Insert data into FactTwoWheel and DimPopulation
                        fact_inserts = []
                        population_inserts = []
                        for index, row in merged_data.iterrows():
                            fact_inserts.append({
                                'date': row['date'].date(),
                                'latitude': row['latitude'],
                                'longitude': row['longitude'],
                                'meanoccupation': row['occupied_spot_number_mean'],
                                'percentoccupation': row['occupied_perc_mean'],
                                'minoccupation': row['occupied_spot_number_min'],
                                'maxoccupation': row['occupied_spot_number_max'],
                                'totalspotnumber': row['total_spot_number'],
                                'locationid': row['locationid']
                            })
                            population_inserts.append({
                                'freguesia': row['freguesia'],
                                'locationid': row['locationid'],
                                'genero': row['genero'],
                                'faixa_etaria': row['faixa_etaria'],
                                'count': row['count']
                            })

                        try:
                            connection.execute(pg_insert(fact_two_wheel).on_conflict_do_nothing(), fact_inserts)
                            connection.execute(pg_insert(dim_population).on_conflict_do_nothing(), population_inserts)
                            connection.commit()  # Commit the transaction to ensure data is saved
                        except SQLAlchemyError as e:
                            print(f"An error occurred during data insertion: {e}")
                    else:
                        print("No data to insert into FactTwoWheel or DimPopulation.")

                print("Data insertion completed successfully!")

            except KeyError as e:
                print(f"Column not found in the DataFrame: {e}")
            except SQLAlchemyError as e:
                print(f"An error occurred with SQLAlchemy: {e}")
            except Exception as e:
                print(f"An unexpected error occurred: {e}")

# %%
insert_data_to_db(full_table, host, port, database, user, password, schema)

# %% [markdown]
# ## Final 2 table version

# %%
# PostgreSQL connection details
host = 'localhost'
port = 5432
database = 'datawarehouse'
schema='testschema'
user = 'postgres'
password = 'password123'

input_bucket_name = "preprocessed"

# Load current files
object_name_2wheel = "twowheel/2wheel_20240610230610.parquet"

# %%
# Read the 2 wheel Parquet file from MinIO
data = read_parquet_from_minio(minio_endpoint, access_key, secret_key, input_bucket_name, object_name_2wheel)

# %%
data
# Out:
#                                                      id  \
# 0     urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 1     urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 2     urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 3     urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# 4     urn:ngsi-ld:OnStreetParking:porto:cmp:001b74a9...
# ...                                                 ...
# 1771  urn:ngsi-ld:OnStreetParking:porto:cmp:fe5304ff...
# 1772  urn:ngsi-ld:OnStreetParking:porto:cmp:fe5304ff...
# 1773  urn:ngsi-ld:OnStreetParking:porto:cmp:fe5304ff...
# 1774  urn:ngsi-ld:OnStreetParking:porto:cmp:fe5304ff...
# 1775  urn:ngsi-ld:OnStreetParking:porto:cmp:fe5304ff...
#
#                    street_address   latitude  longitude                date  \
# 0     Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-05-31 20:58:09
# 1     Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-01 12:48:22
# 2     Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-02 23:45:04
# 3     Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-03 22:01:44
# 4     Av Dr Antunes Guimarães 912  41.170801  -8.656739 2024-06-04 22:19:15
# ...                           ...        ...        ...                 ...
# 1771       R Dr Aarao Lacerda 502  41.167479  -8.659702 2024-06-03 22:01:44
# 1772       R Dr Aarao Lacerda 502  41.167479  -8.659702 2024-06-04 22:19:15
# 1773       R Dr Aarao Lacerda 502  41.167479  -8.659702 2024-06-05 20:00:01
# 1774       R Dr Aarao Lacerda 502  41.167479  -8.659702 2024-06-06 22:52:59
# 1775       R Dr Aarao Lacerda 502  41.167479  -8.659702 2024-06-07 21:10:02
#
#       occupied_spot_number_mean  occupied_spot_number_max  \
# 0                           3.0                       3.0
# 1                           2.5                       3.0
# 2                           2.5                       3.0
# 3                           3.0                       3.0
# 4                           5.0                       7.0
# ...                         ...                       ...
# 1771                        0.5                       1.0
# 1772                        0.0                       0.0
# 1773                        0.0                       0.0
# 1774                        1.5                       3.0
# 1775                        2.5                       3.0
#
#       occupied_spot_number_min  occupied_perc_mean  occupied_perc_max  \
# 0                          3.0                30.0               30.0
# 1                          2.0                25.0               30.0
# 2                          2.0                25.0               30.0
# 3                          3.0                30.0               30.0
# 4                          3.0                50.0               70.0
# ...                        ...                 ...                ...
# 1771                       0.0                 5.0               10.0
# 1772                       0.0                 0.0                0.0
# 1773                       0.0                 0.0                0.0
# 1774                       0.0                15.0               30.0
# 1775                       2.0                25.0               30.0
#
#       occupied_perc_min concelho  \
# 0                  30.0    Porto
# 1                  20.0    Porto
# 2                  20.0    Porto
# 3                  30.0    Porto
# 4                  30.0    Porto
# ...                 ...      ...
# 1771                0.0    Porto
# 1772                0.0    Porto
# 1773                0.0    Porto
# 1774                0.0    Porto
# 1775               20.0    Porto
#
#                                               freguesia  total_spot_number  \
# 0                                               Ramalde                 10
# 1                                               Ramalde                 10
# 2                                               Ramalde                 10
# 3                                               Ramalde                 10
# 4                                               Ramalde                 10
# ...                                                 ...                ...
# 1771  União das freguesias de Aldoar, Foz do Douro e...                 10
# 1772  União das freguesias de Aldoar, Foz do Douro e...                 10
# 1773  União das freguesias de Aldoar, Foz do Douro e...                 10
# 1774  União das freguesias de Aldoar, Foz do Douro e...                 10
# 1775  União das freguesias de Aldoar, Foz do Douro e...                 10
#
#       locationid
# 0            181
# 1            181
# 2            181
# 3            181
# 4            181
# ...          ...
# 1771         175
# 1772         175
# 1773         175
# 1774         175
# 1775         175
#
# [1776 rows x 15 columns]

# %%
def populate_tables(data, host, port, database, user, password, schema):
    # Ensure all column names are lowercase
    data.columns = map(str.lower, data.columns)

    # Create LocationID in the data DataFrame
    location_groups = data.groupby(['latitude', 'longitude']).ngroup() + 1
    data['locationid'] = location_groups

    # Establish connection to the PostgreSQL database
    engine = connect_to_postgresql(host, port, database, user, password, schema)

    if engine is not None:
        metadata = MetaData(schema=schema)
        try:
            metadata.reflect(bind=engine)

            # Access the required tables
            dim_location = Table('dimlocation', metadata, autoload_with=engine, schema=schema)
            fact_two_wheel = Table('facttwowheel', metadata, autoload_with=engine, schema=schema)

            with engine.connect() as connection:
                transaction = connection.begin()
                try:
                    # Insert unique locations into DimLocation with conflict resolution
                    unique_locations = data[['locationid', 'latitude', 'longitude', 'concelho', 'freguesia']].drop_duplicates()
                    location_inserts = unique_locations.to_dict(orient='records')
                    insert_statement = pg_insert(dim_location).values(location_inserts)
                    upsert_statement = insert_statement.on_conflict_do_nothing(index_elements=['latitude', 'longitude'])
                    connection.execute(upsert_statement)

                    # Commit the transaction to save data to DimLocation
                    transaction.commit()
                except SQLAlchemyError as e:
                    transaction.rollback()
                    print(f"Error during DimLocation insertion: {e}")

                # Start a new transaction for FactTwoWheel data insertion
                transaction = connection.begin()
                try:
                    # Verify data exists before insertion
                    if not data.empty:
                        # Insert data into FactTwoWheel
                        fact_inserts = []
                        for index, row in data.iterrows():
                            fact_inserts.append({
                                'date': row['date'].date(),  # Directly use the date part of the Timestamp
                                'latitude': row['latitude'],
                                'longitude': row['longitude'],
                                'meanoccupation': row['occupied_spot_number_mean'],
                                'percentoccupation': row['occupied_perc_mean'],
                                'minoccupation': row['occupied_spot_number_min'],
                                'maxoccupation': row['occupied_spot_number_max'],
                                'totalspotnumber': row['total_spot_number'],
                                'locationid': row['locationid']  # Use the precomputed LocationID
                            })

                        connection.execute(pg_insert(fact_two_wheel).on_conflict_do_nothing(), fact_inserts)

                        # Commit the transaction to save data to FactTwoWheel
                        transaction.commit()
                    else:
                        print("No data to insert into FactTwoWheel.")
                except SQLAlchemyError as e:
                    transaction.rollback()
                    print(f"Error during FactTwoWheel insertion: {e}")

            print("Data insertion completed successfully!")

        except KeyError as e:
            print(f"Column not found in the DataFrame: {e}")
        except SQLAlchemyError as e:
            print(f"Error with SQLAlchemy: {e}")
        except Exception as e:
            print(f"Unexpected error: {e}")

# %%
populate_tables(data, host, port, database, user, password, schema)
# Out:
# Connected to PostgreSQL successfully!
# Data insertion completed successfully!

# %% [markdown]
# # SPARK and Geocode tests (Legacy for reference only)

# %% [markdown]
# ### Geocoding tests

# %%
# Check the outputs of the geocoding
geolocator = Nominatim(user_agent="get_location")
geocode = RateLimiter(geolocator.reverse, min_delay_seconds=1)
location = geocode("41.158887, -8.628684",exactly_one=True)
address = location.raw

# %%
address
# Out:
# {'place_id': 247184657,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'node',
#  'osm_id': 8903663010,
#  'lat': '41.1585937',
#  'lon': '-8.6280332',
#  'class': 'amenity',
#  'type': 'bank',
#  'place_rank': 30,
#  'importance': 9.99999999995449e-06,
#  'addresstype': 'amenity',
#  'name': 'Banco CTT',
#  'display_name': 'Banco CTT, 74, Praça Mouzinho de Albuquerque, Ramada Alta, Cedofeita, Cedofeita, Santo Ildefonso, Sé, Miragaia, São Nicolau e Vitória, Porto, 4100-999, Portugal',
#  'address': {'amenity': 'Banco CTT',
#   'house_number': '74',
#   'road': 'Praça Mouzinho de Albuquerque',
#   'neighbourhood': 'Ramada Alta',
#   'suburb': 'Cedofeita',
#   'city_district': 'Cedofeita, Santo Ildefonso, Sé, Miragaia, São Nicolau e Vitória',
#   'city': 'Porto',
#   'county': 'Porto',
#   'ISO3166-2-lvl6': 'PT-13',
#   'postcode': '4100-999',
#   'country': 'Portugal',
#   'country_code': 'pt'},
#  'boundingbox': ['41.1585437', '41.1586437', '-8.6280832', '-8.6279832']}

# %%
# Testing Google version

api_key = 'AIzaSyDbmerooiniS0lhSGKr-ogdyXgTgKGJL6w'

geolocator = GoogleV3(api_key=api_key)
geocode = RateLimiter(geolocator.reverse, min_delay_seconds=1)

location = geocode("41.158887, -8.628684", exactly_one=True)
address_google = location.raw

# %%
address_google
# Out:
# {'address_components': [{'long_name': '41',
#    'short_name': '41',
#    'types': ['street_number']},
#   {'long_name': 'Praça de Mouzinho de Albuquerque',
#    'short_name': 'Praça de Mouzinho de Albuquerque',
#    'types': ['route']},
#   {'long_name': 'Porto',
#    'short_name': 'Porto',
#    'types': ['locality', 'political']},
#   {'long_name': 'União das freguesias de Cedofeita, Santo Ildefonso, Sé, Miragaia, São Nicolau e Vitória',
#    'short_name': 'União das freguesias de Cedofeita, Santo Ildefonso, Sé, Miragaia, São Nicolau e Vitória',
#    'types': ['administrative_area_level_3', 'political']},
#   {'long_name': 'Porto',
#    'short_name': 'Porto',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'Porto',
#    'short_name': 'Porto',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'Portugal',
#    'short_name': 'PT',
#    'types': ['country', 'political']},
#   {'long_name': '4050',
#    'short_name': '4050',
#    'types': ['postal_code', 'postal_code_prefix']}],
#  'formatted_address': 'Praça de Mouzinho de Albuquerque 41, 4050 Porto, Portugal',
#  'geometry': {'location': {'lat': 41.1589552, 'lng': -8.6286686},
#   'location_type': 'ROOFTOP',
#   'viewport': {'northeast': {'lat': 41.1603041802915,
#     'lng': -8.627319619708498},
#    'southwest': {'lat': 41.15760621970851, 'lng': -8.6300175802915}}},
#  'place_id': 'ChIJQbZMlKdlJA0RsEf1x90QUOw',
#  'plus_code': {'compound_code': '595C+HG Porto, Portugal',
#   'global_code': '8CHH595C+HG'},
#  'types': ['street_address']}

# %%
# Helper function to geocode and extract freguesia and concelho from lat lon using Geopy Nominatim
def get_location_info_latlon(lat, lon):
    geolocator = Nominatim(user_agent="get_location")
    geocode = RateLimiter(geolocator.reverse, min_delay_seconds=1)
    try:
        location = geocode(f"{lat}, {lon}",exactly_one=True)
        address = location.raw.get('address', {})
        # Freguesia is in 'suburb'
        freguesia = address.get('suburb', '')
        # Concelho is in 'county'
        concelho = address.get('city', '')
        # Post code
        post_code = address.get('postcode', '')
        return pd.Series([freguesia, concelho, post_code])
    except Exception as e:
        return pd.Series(['', '', ''])

# %%
google_api_key = 'AIzaSyDbmerooiniS0lhSGKr-ogdyXgTgKGJL6w'

# %%
# Initialize global row counters
nominatim_counter = 0
google_counter = 0

def get_location_info_latlon_v2(lat, lon, google_api_key):
    global nominatim_counter, google_counter
    try:
        # Initialize Nominatim geocoder
        nominatim_geolocator = Nominatim(user_agent="get_location")
        nominatim_geocode = RateLimiter(nominatim_geolocator.reverse, min_delay_seconds=1)

        # Try with Nominatim
        location = nominatim_geocode(f"{lat}, {lon}", exactly_one=True)
        if location:
            address = location.raw.get('address', {})
            # Freguesia in priority order: city_district, suburb, town
            freguesia = address.get('city_district', '') or address.get('suburb', '') or address.get('town', '')
            concelho = address.get('city', '') or address.get('county', '')
            post_code = address.get('postcode', '')  # Post code

            # If Nominatim provides all needed information
            if freguesia and concelho and post_code:
                nominatim_counter += 1
                return pd.Series([freguesia, concelho, post_code])

        # If Nominatim fails, initialize Google Maps geocoder
        google_geolocator = GoogleV3(api_key=google_api_key)
        google_geocode = RateLimiter(google_geolocator.reverse, min_delay_seconds=1)

        # Try with Google Maps
        location = google_geocode((lat, lon))
        if location:
            address_components = location[0].raw['address_components']
            freguesia = ''
            concelho = ''
            post_code = ''
            for component in address_components:
                if 'sublocality_level_1' in component['types'] or 'locality' in component['types']:
                    freguesia = component['long_name']
                elif 'administrative_area_level_2' in component['types']:
                    concelho = component['long_name']
                elif 'postal_code' in component['types']:
                    post_code = component['long_name']
            google_counter += 1
            return pd.Series([freguesia, concelho, post_code])

        return pd.Series(['', '', ''])
    except Exception as e:
        return pd.Series(['', '', ''])

# %%
mapping_dict = {"4410001-4410999": {"concelho": "Vila Nova de Gaia", "freguesia": "Arcozelo"},
    "4430001-4430999": {"concelho": "Vila Nova de Gaia", "freguesia": "Avintes"},
    "4410001-4410999": {"concelho": "Vila Nova de Gaia", "freguesia": "Canelas"},
    "4400001-4400999": {"concelho": "Vila Nova de Gaia", "freguesia": "Canidelo"},
    "4415001-4415999": {"concelho": "Vila Nova de Gaia", "freguesia": ["Crestuma", "União das Freguesias de Grijó e Sermonde", "União das Freguesias de Pedroso e Seixezelo", "União das Freguesias de Sandim, Olival, Lever e Crestuma", "União das Freguesias de Serzedo e Perosinho"]},
    "4405001-4405999": {"concelho": "Vila Nova de Gaia", "freguesia": ["União das Freguesias de Gulpilhares e Valadares", "Madalena"]},
    "4430001-4430999": {"concelho": "Vila Nova de Gaia", "freguesia": ["União das Freguesias de Mafamude e Vilar do Paraíso", "Oliveira do Douro"]},
    "4400001-4400999": {"concelho": "Vila Nova de Gaia", "freguesia": "União das Freguesias de Santa Marinha e São Pedro da Afurada"},
    "4430001-4430999": {"concelho": "Vila Nova de Gaia", "freguesia": "Vilar de Andorinho"}}

# %%
def map_postal_code(postal_code, mapping):
    postal_code_num = int(postal_code.replace('-', ''))
    for key, value in mapping.items():
        start, end = map(int, key.split('-'))
        if start <= postal_code_num <= end:
            return pd.Series([value['concelho'], value['freguesia']])
    return pd.Series([None, None])

# %%
# Function to geocode and extract freguesia and concelho using street address using Geopy Nominatim
def get_location_info_address(address):
    geolocator = Nominatim(user_agent="get_location_address")
    geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
    try:
        location = geocode(address, exactly_one=True)
        if location:
            address_detail = location.raw.get('address', {})
            freguesia = address_detail.get('suburb', '')
            concelho = address_detail.get('city', '')
            post_code = address_detail.get('postcode', '')
            return pd.Series([freguesia, concelho, post_code])
        else:
            return pd.Series(['', '', ''])
    except Exception as e:
        return pd.Series(['', '', ''])

# %% [raw]
# def process_data(df_raw):
#     try:
#         # Get freguesia and concelho from the street address using latitude and longitude
#         df_raw[['freguesia', 'concelho', 'codigo_postal']] = df_raw.apply(lambda row: get_location_info_latlon(row['latitude'], row['longitude']), axis=1)
#
#         # Identify rows where freguesia is still empty after the first round of geocoding
#         rows_to_geocode_address = df_raw[df_raw['freguesia'] == '']
#
#         # Get freguesia and concelho from the street address for remaining rows
#         if not rows_to_geocode_address.empty:
#             rows_to_geocode_address[['freguesia', 'concelho', 'codigo_postal']] = rows_to_geocode_address['street_address'].apply(get_location_info_address)
#
#         # Concatenate the results
#         df_processed = pd.concat([df_raw[df_raw['freguesia'] != ''], rows_to_geocode_address])
#
#         # Calculate occupied spots percentage
#         df_processed["occupied_perc"] = df_processed["occupied_spot_number"] / df_processed["total_spot_number"] * 100
#
#         # Create aggregated dataframe
#         df_aggregated = df_processed.groupby(by=['id', 'date', 'street_address', 'latitude', 'longitude', 'freguesia', 'concelho', 'codigo_postal']).agg(
#             occupied_spot_number_mean=('occupied_spot_number', 'mean'),
#             occupied_perc_mean=('occupied_perc', 'mean'),
#             occupied_spot_number_max=('occupied_spot_number', 'max'),
#             occupied_spot_number_min=('occupied_spot_number', 'min'),
#             total_spot_number=('total_spot_number', 'first'),
#         ).reset_index()
#
#         return df_aggregated
#
#     except Exception as e:
#         print(f"An error occurred while processing the data: {e}")
#         return None

# %% [raw]
# def geocode_aggregated(df_processed, google_api_key):
#     global nominatim_counter, google_counter
#     try:
#         # Reset counters
#         nominatim_counter = 0
#         google_counter = 0
#
#         # Apply geocoding function to each row
#         df_processed[['freguesia', 'concelho', 'codigo_postal']] = df_processed.apply(
#             lambda row: get_location_info_latlon_v2(row['latitude'], row['longitude'], google_api_key), axis=1
#         )
#
#         # Print counters
#         print(f"Nominatim processed: {nominatim_counter} rows")
#         print(f"Google Maps processed: {google_counter} rows")
#
#         return df_processed
#     except Exception as e:
#         print(f"An error occurred while geocoding the data: {e}")
#         return None

# %% [raw]
# df_final = geocode_aggregated(df_processed, google_api_key)

# %%
mapping_dict = {"4410001-4410999": {"concelho": "Vila Nova de Gaia", "freguesia": "Arcozelo"},
    "4430001-4430999": {"concelho": "Vila Nova de Gaia", "freguesia": "Avintes"},
    "4410001-4410999": {"concelho": "Vila Nova de Gaia", "freguesia": "Canelas"},
    "4400001-4400999": {"concelho": "Vila Nova de Gaia", "freguesia": "Canidelo"},
    "4415001-4415999": {"concelho": "Vila Nova de Gaia", "freguesia": ["Crestuma", "União das Freguesias de Grijó e Sermonde", "União das Freguesias de Pedroso e Seixezelo", "União das Freguesias de Sandim, Olival, Lever e Crestuma", "União das Freguesias de Serzedo e Perosinho"]},
    "4405001-4405999": {"concelho": "Vila Nova de Gaia", "freguesia": ["União das Freguesias de Gulpilhares e Valadares", "Madalena"]},
    "4430001-4430999": {"concelho": "Vila Nova de Gaia", "freguesia": ["União das Freguesias de Mafamude e Vilar do Paraíso", "Oliveira do Douro"]},
    "4400001-4400999": {"concelho": "Vila Nova de Gaia", "freguesia": "União das Freguesias de Santa Marinha e São Pedro da Afurada"},
    "4430001-4430999": {"concelho": "Vila Nova de Gaia", "freguesia": "Vilar de Andorinho"}}

# %%
def map_postal_code(postal_code, mapping):
    postal_code_num = int(postal_code.replace('-', ''))
    for key, value in mapping.items():
        start, end = map(int, key.split('-'))
        if start <= postal_code_num <= end:
            return pd.Series([value['concelho'], value['freguesia']])
    return pd.Series([None, None])

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def get_postcode_info_latlon_google(lat, lon, google_api_key):
    try:
        logging.info(f"Processing lat: {lat}, lon: {lon}")
        google_geolocator = GoogleV3(api_key=google_api_key)
        google_geocode = RateLimiter(google_geolocator.reverse, min_delay_seconds=1)

        location = google_geocode((lat, lon))
        logging.info(f"API response for lat: {lat}, lon: {lon} - {location}")

        if location and isinstance(location, list) and len(location) > 0:
            address_components = location[0].raw['address_components']
            freguesia = ''
            concelho = ''
            post_code = ''
            for component in address_components:
                if 'administrative_area_level_3' in component['types'] and 'political' in component['types']:
                    freguesia = component['long_name']
                elif 'administrative_area_level_2' in component['types'] and 'political' in component['types']:
                    concelho = component['long_name']
                elif 'postal_code' in component['types']:
                    post_code = component['long_name']
            logging.info(f"Found address: freguesia={freguesia}, concelho={concelho}, post_code={post_code}")
            return pd.Series([freguesia, concelho, post_code], index=['freguesia', 'concelho', 'post_code'])
        else:
            logging.warning(f"No valid location found for lat: {lat}, lon: {lon}")
            return pd.Series(['', '', ''], index=['freguesia', 'concelho', 'post_code'])
    except Exception as e:
        logging.error(f"Error processing lat: {lat}, lon: {lon} - {e}")
        return pd.Series(['', '', ''], index=['freguesia', 'concelho', 'post_code'])

# %% [raw]
# def geocode_aggregated(df_processed, google_api_key):
#     global nominatim_counter, google_counter
#     try:
#         # Reset counters
#         nominatim_counter = 0
#         google_counter = 0
#
#         # Apply geocoding function to each row
#         df_processed[['freguesia', 'concelho', 'codigo_postal']] = df_processed.apply(
#             lambda row: get_location_info_latlon_v2(row['latitude'], row['longitude'], google_api_key), axis=1
#         )
#
#         # Print counters
#         print(f"Nominatim processed: {nominatim_counter} rows")
#         print(f"Google Maps processed: {google_counter} rows")
#
#         return df_processed
#     except Exception as e:
#         print(f"An error occurred while geocoding the data: {e}")
#         return None

# %% [markdown]
# ## Spark tests

# %%
json_data[0]
# Out:
# {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:7cfee26e-b86c-4814-aadc-4b7d11e6010d',
#  'type': 'OnStreetParking',
#  'address': {'type': 'PostalAddress',
#   'value': {'addressCountry': None,
#    'addressLocality': None,
#    'addressRegion': None,
#    'postOfficeBoxNumber': None,
#    'postalCode': None,
#    'streetAddress': 'Pc Mouzinho De Albuquerque 56'},
#   'metadata': {}},
#  'allowedVehicleType': {'type': 'Array',
#   'value': ['twoWheeledVehicle'],
#   'metadata': {}},
#  'availableSpotNumber': {'type': 'Number', 'value': 10, 'metadata': {}},
#  'dataProvider': {'type': 'Text', 'value': 'cmp', 'metadata': {}},
#  'description': {'type': 'Text',
#   'value': 'Praça de Mouzinho de Albuquerque',
#   'metadata': {}},
#  'location': {'type': 'geo:json',
#   'value': {'type': 'Point', 'coordinates': [-8.628683966, 41.158887288]},
#   'metadata': {}},
#  'occupiedSpotNumber': {'type': 'Number', 'value': 0, 'metadata': {}},
#  'totalSpotNumber': {'type': 'Number', 'value': 10, 'metadata': {}},
#  'vehicle_ids': {'type': 'Array', 'value': [], 'metadata': {}}}

# %%
transformed_data = []
for entry in json_data:
    transformed_entry = {
        'id': entry['id'],
        'type': entry['type'],
        'address': json.dumps(entry.get('address', {}).get('value', {})),
        'allowedVehicleType': entry.get('allowedVehicleType', {}).get('value', []),
        'availableSpotNumber': entry.get('availableSpotNumber', {}).get('value', None),
        'dataProvider': entry.get('dataProvider', {}).get('value', None),
        'description': entry.get('description', {}).get('value', ''),
        'location': json.dumps(entry.get('location', {}).get('value', {})),
        'occupiedSpotNumber': entry.get('occupiedSpotNumber', {}).get('value', None),
        'totalSpotNumber': entry.get('totalSpotNumber', {}).get('value', None),
        'vehicle_ids': entry.get('vehicle_ids', {}).get('value', [])
        }
    transformed_data.append(transformed_entry)

# %%
transformed_data
# Out:
# [{'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:7cfee26e-b86c-4814-aadc-4b7d11e6010d',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Pc Mouzinho De Albuquerque 56"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Praça de Mouzinho de Albuquerque',
#   'location': '{"type": "Point", "coordinates": [-8.628683966, 41.158887288]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:a7c593b1-1dd2-4a01-bd21-48c35fa0ad93',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Passeio Das Virtudes 12"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 4,
#   'dataProvider': 'cmp',
#   'description': 'Passeio das Virtudes',
#   'location': '{"type": "Point", "coordinates": [-8.618336288, 41.14429301]}',
#   'occupiedSpotNumber': 6,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:2440b963-c420-5380-b646-2cd750a57de5',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:ac8b0cd8-942f-55e1-bae3-bc0d6ac5174e',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:545dcd1d-4930-4d69-97a2-4150087832e9',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:4c66249a-4987-5c5d-8cd4-b375997b3a0d expires@2024-05-26T12:50:50.00Z',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:f656ee29-6178-422c-80fb-922154f17e0d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:fc6027af-ac9a-49e5-b101-3c4b89cc0d52']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:2a64f748-dbf4-4dab-93ad-f4debb12413f',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Cpo Martires Da Patria 174"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': -6,
#   'dataProvider': 'cmp',
#   'description': 'Campo dos Mártires da Pátria',
#   'location': '{"type": "Point", "coordinates": [-8.617372732, 41.145244637]}',
#   'occupiedSpotNumber': 16,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:c6ad0e6a-6cc7-5ceb-aa0b-f55de10fe719',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:c4581378-6f9d-5ac1-b933-be6c2d80611d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:0c24ebe0-45e2-5e40-9c12-1f94d4b8012b',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:2f0633f1-2f5e-5781-8083-6d7a8d7d9911',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:2e69a819-49e3-4c8a-ada0-c9e033f36987',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:926f7ce7-cfe4-5cdc-ae35-adb2ff6f9179',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:7b87d149-2cc4-5682-8e0c-f0334b9a2b4a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:ea8963ca-318d-4f0d-8013-f839387b6b71',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:df7c3431-488e-4368-b779-55be341be4dc',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:02345544-bc2f-43a7-a739-9a8794f84647',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:f86911a1-d37a-439c-9bef-579f81e6b8b4',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:3f4ab4fd-c757-4fea-be9f-1fdd6f9b9f4d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:86f77d17-a70a-4807-9ce7-5d694de1acd8',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:af4a5e13-13b4-409c-9268-6ed9b03107da expires@2024-05-26T03:03:42.00Z',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:31e3629f-4e4a-41d7-8814-698d89fd4e3a expires@2024-05-26T03:03:39.00Z',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:95048891-ad49-509e-ac5b-9348e1439dd9']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:37f0cf74-4858-4dd5-a881-2273b2f20a3e',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Rua de S\\u00e1 da Bandeira 637"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 8,
#   'dataProvider': 'cmp',
#   'description': 'Pátio do Bolhão',
#   'location': '{"type": "Point", "coordinates": [-8.606654252, 41.151679793]}',
#   'occupiedSpotNumber': 2,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:10f0a309-99c2-5794-91e9-14e32f1d448a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:40af4898-1798-54ca-a3bd-145f433dee58']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:e4a90d10-e61f-4444-8452-7077501f3682',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R D Jo\\u00e3o Coutinho 30"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Engenheiro Ferreira Dias',
#   'location': '{"type": "Point", "coordinates": [-8.64838512, 41.177007166]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:5ddbfd03-19e9-4e93-8736-b19dd43698a5',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R D Jo\\u00e3o Coutinho 201"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Rua de D. João Coutinho',
#   'location': '{"type": "Point", "coordinates": [-8.646124685, 41.176978338]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:b0b59b5a-c0e8-4ef2-9c58-beec56b2d1c5']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:a7e63e49-4a57-4f4a-93a3-337018b811a3',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Julio Dinis 206"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Júlio Dinis',
#   'location': '{"type": "Point", "coordinates": [-8.625961067, 41.150684828]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:189ab8d4-cd62-4920-be20-93df832e1003',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Infanta D Maria 135"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Rua da Infanta D. Maria',
#   'location': '{"type": "Point", "coordinates": [-8.621889042, 41.158904525]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:2b74f655-79f3-5523-8c2c-5fcaa1802d13']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:a2653849-43c8-4042-ab3f-f591d6779bcd',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Av Boavista 68"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 4,
#   'dataProvider': 'cmp',
#   'description': 'Avenida da Boavista',
#   'location': '{"type": "Point", "coordinates": [-8.624695365, 41.157261198]}',
#   'occupiedSpotNumber': 6,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:4c8aacd9-bca4-56e8-9a52-510491008ed8',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:6dcb3c81-17de-4a27-b4c1-9b8a7977e4df',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:720db255-fdd9-4bd8-bd60-9d677e094cdf',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:95c68b94-bb41-4f0b-b7d5-246c24badf35',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:18736bb5-fedc-4879-8625-7dbb819098f5',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:22862787-2bd2-5e4f-b94f-15f0924688d2']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:c84c2895-5884-4a04-90ed-fe61b67c37e2',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Al E\\u00e7a De Queir\\u00f3s 37"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Alameda de Eça de Queirós',
#   'location': '{"type": "Point", "coordinates": [-8.593701737, 41.162499468]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:61c3fc23-1ed1-4ee2-9da1-e954c4c84e77']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:19738b44-97b6-4bc7-87b9-074ba2411fea',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R \\u00c1lvares Cabral 34"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 5,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Álvares Cabral',
#   'location': '{"type": "Point", "coordinates": [-8.618470396, 41.155089241]}',
#   'occupiedSpotNumber': 5,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:f9102d83-564f-41a5-a686-d8db63281126',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:6bb69099-6630-41a2-b090-07010456d51f',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:67fd2617-675d-4ad0-bfaa-a22d0a4165be',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:bc825179-e6bb-42f9-a182-88c906498bb4',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:7518898c-5dba-4069-b566-65f5054fd139']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:99ffb637-a471-4f49-8764-fe6a5a8ef5fb',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R 31 De Janeiro 223"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Rua de 31 de Janeiro',
#   'location': '{"type": "Point", "coordinates": [-8.607355209, 41.146183996]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:fb603ae2-4f03-5f86-9c8f-7ef3b1daa84d']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:029781e2-004d-40c4-bd80-853d41743ec8',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Vilar 16"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 7,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Vilar',
#   'location': '{"type": "Point", "coordinates": [-8.626752169, 41.148883785]}',
#   'occupiedSpotNumber': 3,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:c0f5ab20-3bc4-5491-94c6-b13152063d1d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:b4cfdac7-c6c6-4b2c-a557-585188ed4abb',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:ee682357-7e89-4f6d-895b-0d9460af3329']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:352f4411-b9d3-4e98-9090-5562148961d8',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Mouzinho Da Silveira 137"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Mouzinho da Silveira',
#   'location': '{"type": "Point", "coordinates": [-8.61336457, 41.143413228]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:b6a537b2-da65-4173-9f19-5463b13ee0b2',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Passeio Alegre 544"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 11,
#   'dataProvider': 'cmp',
#   'description': 'Avenida de D. Carlos I',
#   'location': '{"type": "Point", "coordinates": [-8.667488714, 41.147478277]}',
#   'occupiedSpotNumber': 4,
#   'totalSpotNumber': 15,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:c6a09199-4a92-4eec-8174-517101a9c831',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:a2b68df3-3be6-42a2-8890-71efcde6f14f',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:40e12812-f6f1-472d-878e-b609c113c9d4',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:78dfd0ab-5765-4096-b6e6-47e465a00fa5']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:b8155d7e-28b8-4ebe-b051-f4e3e34c76ae',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Clemente Meneres 105"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Professor Vicente José de Carvalho',
#   'location': '{"type": "Point", "coordinates": [-8.618058664, 41.147980585]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:f59d66fe-5759-5350-ad02-232b205f3545']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:1e057dec-0aa8-4f6f-80c8-ea91c61920b0',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Cha 26"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Rua Tareija Vaz de Altaro',
#   'location': '{"type": "Point", "coordinates": [-8.610713074, 41.143623875]}',
#   'occupiedSpotNumber': 11,
#   'totalSpotNumber': 20,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:7d032b22-22b7-4286-a7cb-ba7d0f0ac85f',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:2cd10414-57a2-4083-8804-9d826be6d1ad',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:62417810-e356-4546-85ea-0041b703a2d6',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:36cbbfaa-d9dd-4180-944a-6b491afe6176',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:5110c41c-757f-4b9b-a3b7-f343748b87f5',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:circ:8e994401-5a61-49d3-a557-509031ec3ae4',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:928f1a5c-acab-42d3-943a-51625aeb735d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:03b012b4-81e7-486f-8853-745a299bc4cf',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:d48339ad-0eae-4f00-b4f0-0c013c1d9f1c',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:d6aa682b-ab6b-4581-b618-b0cf79a0ee8c',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:a9a0590b-8df6-4929-a971-5f7a6702a0b2']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:5209baad-abdc-49e8-8e59-ec53f9108f9c',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Av Marechal Gomes Da Costa 1551"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Avenida do Marechal Gomes da Costa',
#   'location': '{"type": "Point", "coordinates": [-8.671648458, 41.155453438]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:f8467a77-0beb-433c-9d2b-38524bbb89f3',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Gon\\u00e7alo Crist\\u00f3v\\u00e3o 26"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 2,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Gonçalo Cristóvão',
#   'location': '{"type": "Point", "coordinates": [-8.605519608, 41.153398943]}',
#   'occupiedSpotNumber': 8,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:7ccd912a-a027-5b5c-a170-10f8ea98a7cc',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:97780e77-c8aa-5835-9dc7-acc91024d045',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:e3fad084-62ae-5e56-b6e0-0ccb9d19eda3',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:6a521575-e52c-567c-b61a-74d9abc97ed2',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:60e814f9-5d59-5af2-a169-eb1251bac4f2',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:83040473-ef9c-533b-805e-1a2c7e666836',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:156cb4bd-a6df-5c92-9690-e4916ba0c53e',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:feec0231-d1d2-53cb-ad49-4b2cf8cc8d68']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:463c555e-88df-4228-a3f9-3e43c3fa3971',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R S Catarina 1396"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 6,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Santa Catarina',
#   'location': '{"type": "Point", "coordinates": [-8.604501971, 41.158547716]}',
#   'occupiedSpotNumber': 4,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:3a679b68-e68e-4fef-9ab7-2012d04522bf',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:fde08d47-0968-41e3-a040-ed3a97966863',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:a56c80ef-24f5-46a3-8407-30a08a3a17a2',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:7695742e-c67e-4e1e-a7eb-032dba39e6ec']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:9e011884-56ca-4d2d-81c2-662e70ceab82',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Pra\\u00e7a do Bom Sucesso 74 - 90"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 5,
#   'dataProvider': 'cmp',
#   'description': 'Largo de Ferreira Lapa',
#   'location': '{"type": "Point", "coordinates": [-8.628460854, 41.155610565]}',
#   'occupiedSpotNumber': 5,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:adb16fb5-61c8-5773-bd85-0617220aaf67',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:75145e0b-4a39-5c82-bc12-4a99b3717c05',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:a04e7730-9b5e-470c-857a-f45b55ca7136',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:075f1a7e-69b4-5b9f-a875-0e9872d74dec',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:2b56644c-31be-443a-88bc-2e7333f9fd91']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:6e9afc39-5158-41ce-9bf0-574197bff309',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Constituicao 701"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 7,
#   'dataProvider': 'cmp',
#   'description': 'Rua da Constituição',
#   'location': '{"type": "Point", "coordinates": [-8.606562613, 41.162099735]}',
#   'occupiedSpotNumber': 3,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::bicycle:circ:56cb258a-a431-4b44-81b7-1175080a9e28',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:6bbce6da-4323-43a4-856b-35e86f610d67',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:527eb547-8ca3-4693-bcf4-848abf57f1db']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:31ed660a-7aef-4065-9849-f5f4ccbb818e',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Restauracao 200"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Rua da Restauração',
#   'location': '{"type": "Point", "coordinates": [-8.62631091, 41.145417531]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:circ:7777acfd-f71a-4a96-b349-c0e9b3b21ccc']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:eb03d2b0-8d49-4df8-bf97-d7cf7f70cff6',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Rua Actor Ferreira da Silva 100"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Rua D. Frei Vicente da Soledade e Castro',
#   'location': '{"type": "Point", "coordinates": [-8.596201341, 41.176994686]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:32729e47-8170-483f-85b3-287ecdf5b022',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Delfim Maia 440"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Praça de Nove de Abril',
#   'location': '{"type": "Point", "coordinates": [-8.611243879, 41.17262536]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:4bdb45a8-738e-4929-85fe-0261e0124a9a',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Domingos Machado 66"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': -1,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Domingos Machado',
#   'location': '{"type": "Point", "coordinates": [-8.632134047, 41.165292958]}',
#   'occupiedSpotNumber': 11,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:46052dbf-8295-591d-89f7-26d96067cb0f',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:6a35d579-8214-5589-a45b-83565728089a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:32ad4700-6767-5bd4-ba17-fc5d206d1932',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:2ae52715-01ff-5c92-bb1a-4defbc07e0cf',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:82bdda1c-e879-4231-94c9-9e0ff466f619',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:055b68d2-869a-45ae-bfa6-e16a7706d3bc',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:0fee9cf4-0e81-4164-8759-0e87aa53c5a0',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:246ec322-f9d0-5861-962f-80affd438e9c',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:3abcbc6d-e18b-51c7-8ded-5deef1c5613c',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:dae604b8-23aa-5bd0-8872-4e807d762c47',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:3f9435fd-56f1-5c5d-9282-57c6c2bb9fd9']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:5a7c168a-17b1-4769-b9a2-c65b87b6d748',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Alm Leote Do Rego 224"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 3,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Almirante Leote do Rego',
#   'location': '{"type": "Point", "coordinates": [-8.613669099, 41.165233066]}',
#   'occupiedSpotNumber': 7,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:a8208da2-26fa-5ee4-af38-918143d450b8',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:894162be-1a9e-58bf-bc22-e4b8f87aded4',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:0b41c0e7-054d-5a05-ad73-fd0c0752c600',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:cbfe23ae-0e13-5bc3-b755-1f0807064fef',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:9962df95-1a56-55e9-ba0b-e4b1960eecf5',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:e8e7c807-6753-5592-9a71-5d9823691678',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:d193695c-e904-507d-9138-a5e8156e87a5']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:61a861f4-1da7-4fdd-aa20-a9c415475664',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Av Franca 249"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 7,
#   'dataProvider': 'cmp',
#   'description': 'Rua Professor José Augusto Seabra',
#   'location': '{"type": "Point", "coordinates": [-8.629013522, 41.161148242]}',
#   'occupiedSpotNumber': 3,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:circ:61045825-f4d1-46cb-9d20-961a80f10136',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:circ:382a83e8-d23e-4df6-bc21-6c0566f69438',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:731dd5ed-fcbf-48c0-9869-ff72f5cb1fe3']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:a6740d5b-39bf-4b62-b8cf-647aff584baa',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R 5 De Outubro 40"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Cinco de Outubro',
#   'location': '{"type": "Point", "coordinates": [-8.630073898, 41.159052865]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:bd9dcb9b-1fe1-581e-b0d3-2e5aafbd0cb0']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:806fa333-c272-4553-90b7-a829d11d67aa',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Pra\\u00e7a do Bom Sucesso 74 - 90"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 0,
#   'dataProvider': 'cmp',
#   'description': 'Praça do Bom Sucesso',
#   'location': '{"type": "Point", "coordinates": [-8.629478652, 41.155522561]}',
#   'occupiedSpotNumber': 10,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:d1aebdd7-991c-5e8e-95f8-059b71b4a5a0',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:26d28f5d-feb3-583d-a3e0-7309a76004c1',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:f5f3fecc-7699-5b28-b168-671010045f15',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:6773a454-68d0-512c-8324-5366dc16c16d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:1551ba44-3cd1-521c-b591-4a79ce00c13e',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:af46a03e-1afc-57d9-b980-05e872c8c3b5',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:b1558ea6-b4a7-5a85-b923-780a6826da90',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:73a7825d-cdeb-59d0-bb3d-4e3a3dbbe744',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:de08a0aa-b8c6-5acf-9acf-aa50f97470fd',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:1683a64f-e394-583c-97c8-c4ea4da748c9']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:584f478b-7a97-4f0f-af54-58574276b4bc',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Breiner 28"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': -1,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Breiner',
#   'location': '{"type": "Point", "coordinates": [-8.61801528, 41.151503285]}',
#   'occupiedSpotNumber': 11,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:d696db10-a6ce-5ba4-a6e4-00855af94917',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:b79b5be2-9698-5a79-b580-0fec1e90cfe2',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:c96cd3de-c07c-589d-9592-da055e0ae96d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:d1685f7d-b491-5171-9c80-0c47ea5533d8',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:009e5b76-34c5-5683-b4ea-b20f96cccbe4',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:caf6a382-e382-58f4-b3be-67f5be1afd3a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:2dd465db-3a14-5b52-999d-cdc9a7cd95c1',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:4ae9bf6e-9740-5c8c-82b9-010286f4163b',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:2459525b-aed9-5286-bfeb-de2ded6b2dde',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:circ:3c8e01f2-32e7-412d-8122-e44afb1855da',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:da4f2ba7-54af-4499-b654-0afc9de75bca']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:281349fa-a86a-4f52-beaf-02a4b87d5bc6',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Rua de Azevedo Coutinho 39"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 8,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Azevedo Coutinho',
#   'location': '{"type": "Point", "coordinates": [-8.646607424, 41.161087692]}',
#   'occupiedSpotNumber': 2,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:2a71f9f9-bb37-5756-a461-b5b71699c87f',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:419a2a76-65b2-5420-bd23-68adb2b6fea9']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:77f57d66-106b-4300-b89e-716c852de521',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Ferreira Borges 70"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 13,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Ferreira Borges',
#   'location': '{"type": "Point", "coordinates": [-8.61523439, 41.142254452]}',
#   'occupiedSpotNumber': 7,
#   'totalSpotNumber': 20,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:circ:439a26d6-8eb1-430e-96f1-1637a62302b9',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:circ:bc8ec3de-cf35-4690-bfd8-485e935a0ad2',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:07d0cca9-00c2-4b9f-808c-9070f0fff98e',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::bicycle:circ:137a132f-d091-48a8-b8e5-e64b7bcb2956',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:4bae2c77-a093-440b-8149-c3b6c115084a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:768ab41b-2584-47fb-832a-cee34b9baf7a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:71621c21-a38e-4703-b1da-254b76d15844']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:bfc4d0af-7bdd-4571-ade8-510efb21236d',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Sobreiras 594"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 7,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Sobreiras',
#   'location': '{"type": "Point", "coordinates": [-8.660723821, 41.147312776]}',
#   'occupiedSpotNumber': 3,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:7aa61663-51bf-4c09-b262-d60f3f7a56b2',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::bicycle:circ:c0094faf-e80d-4062-9a68-037a7f8e444e',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:98766d2d-c1a2-4c3b-8429-5294ed7bc347']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:923e3679-d953-484b-8e07-d489cb9ac704',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Dr Mauricio Esteves Pereira Pinto 2"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Praça da Corujeira',
#   'location': '{"type": "Point", "coordinates": [-8.579472882, 41.156257923]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:e614e2ce-3c03-4fc0-8d90-7d68e1938604',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Henrique De Sousa Reis 127"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 4,
#   'dataProvider': 'cmp',
#   'description': 'Rua Henrique de Sousa Reis',
#   'location': '{"type": "Point", "coordinates": [-8.590053615, 41.177351653]}',
#   'occupiedSpotNumber': 6,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:12ec5709-4e1a-53da-8687-47728d103db7',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:b4dc327f-7924-5d1f-82cc-420e620574f4',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:b7bbf3d8-293b-5993-8c6c-90c50e989249',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:ecc64823-0d0f-5db2-9b65-afa4853a260c',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:6b705af7-dd9d-5a19-84f3-5977ad82439a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:2da14293-d38e-5b7c-ac99-f74f48b2068e']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:a25110c5-ea45-4924-a5e4-19aafa9bb703',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Gon\\u00e7alo Sampaio 379"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 8,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Gonçalo Sampaio',
#   'location': '{"type": "Point", "coordinates": [-8.630061696, 41.155522375]}',
#   'occupiedSpotNumber': 2,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:f2fbf798-bef8-5b0a-b33a-b24ba7e14457',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:47d19a33-52e0-5479-b712-4e8b040430ec']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:90542a6d-9c76-4957-8f96-446dfd1a21f5',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Travagem 300"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 8,
#   'dataProvider': 'cmp',
#   'description': 'Rua da Travagem',
#   'location': '{"type": "Point", "coordinates": [-8.636102915, 41.165483082]}',
#   'occupiedSpotNumber': 2,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:31864795-742b-548f-bbc9-416dff6cc298',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:fb599e84-a162-49de-9bdc-fc1a5808d9f8']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:65e929f3-6486-4a36-a998-6a4d7042bcf2',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Via Panor\\u00e2mica s/n"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Via Panoramica',
#   'location': '{"type": "Point", "coordinates": [-8.636448751, 41.149900123]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:25a52f0c-d3da-4def-9b99-0a9ff8d4c947']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:69167bb6-35e9-4dab-a225-0b3c12f5ab74',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Entrecampos 334"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 5,
#   'dataProvider': 'cmp',
#   'description': 'Rua das Estrelas',
#   'location': '{"type": "Point", "coordinates": [-8.639247645, 41.150533561]}',
#   'occupiedSpotNumber': 5,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:69288e65-d43d-5b82-b14c-5dbb860d411c',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:35afb27e-aa06-5649-acc2-796dd2c44016',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:edb38792-ce04-5408-9d9a-34a167ce6108',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:5044143a-7228-4713-8e21-20b555f1b9dc',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:cc457e1f-5620-475a-9e59-9ad90e162ac8']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:b35d6036-1127-4047-9659-3afc02b3c8b9',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Prof Bento De Jesus Cara\\u00e7a 189"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 7,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Professor Bento de Jesus Caraça',
#   'location': '{"type": "Point", "coordinates": [-8.597846352, 41.162978239]}',
#   'occupiedSpotNumber': 3,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:6d91c742-3117-4088-8872-1cfca8c47349',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:0627705b-ddf3-4874-be6b-6ec715727c87',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:989b52cd-b8a7-4fa0-aa02-d41972b1ff1a']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:34909e1a-9cf1-431c-9b7d-a040eec64cb4',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Av Dr Antunes Guimar\\u00e3es 68"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Avenida do Dr. Antunes Guimarães',
#   'location': '{"type": "Point", "coordinates": [-8.662388389, 41.16423563]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:c1cf6b75-d43c-47a9-b8f0-97c1868eec9e']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:091416fa-81a3-4f47-aef5-422d671b6214',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Dr Sousa Avides 79"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 1,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Dr. Sousa Avides',
#   'location': '{"type": "Point", "coordinates": [-8.589956335, 41.151139572]}',
#   'occupiedSpotNumber': 9,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:bfe6c0a9-048f-520c-b801-4d403593403c',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:dc8808c5-35a0-5a95-9a49-09fb0fdc5632',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:bd327b64-45df-5274-9b42-cfdba5cef19f',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:e596be80-a1a0-5cc7-81e3-2be19bb982a4',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:881da3ad-6836-5401-9ca7-0a0950d37962',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:f7aba30a-353f-5c78-b207-644b6617e6b1',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:b4d57106-c7fb-5021-8cc5-efc94f2abccb',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:cdc48eaf-77b9-5df9-8b31-8b56b790e6cc',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:85b3d265-2f21-4dba-bdd1-9e1df86725e3']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:0e66c7e0-228f-43b1-b198-2dd8bb44769d',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Al Aquilino Ribeiro 32"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Manuel Pinto de Azevedo',
#   'location': '{"type": "Point", "coordinates": [-8.646929563, 41.172789914]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:63e15c0b-884b-4501-bab2-56870ed9fd24',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Jo\\u00e3o De Barros 226"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 6,
#   'dataProvider': 'cmp',
#   'description': 'Rua de João de Barros',
#   'location': '{"type": "Point", "coordinates": [-8.662831788, 41.154552733]}',
#   'occupiedSpotNumber': 4,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:fc110dc1-6d00-4665-a7ef-94716089ad3b',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:277f6c73-2e79-4be9-9bda-8f8c2945e114',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:b0fff9f8-cb92-4510-a43e-2cc138f60ab0',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:b879e9c5-de37-433a-93d6-657b70f4c040']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:9869a090-d345-4bd8-9e56-4b1e582b7b82',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Molhe 4"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Molhe',
#   'location': '{"type": "Point", "coordinates": [-8.683496502, 41.159405731]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:f1934c75-541f-497e-b1fd-8f3d5209ffed',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Dr Lopo De Carvalho 100"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Currais',
#   'location': '{"type": "Point", "coordinates": [-8.582616498, 41.175020557]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:30b6a5ca-7093-4ab1-9f8c-017d404691a7',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Pc D Afonso V 121"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 7,
#   'dataProvider': 'cmp',
#   'description': 'Praça de D. Afonso V',
#   'location': '{"type": "Point", "coordinates": [-8.666149852, 41.15951815]}',
#   'occupiedSpotNumber': 3,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:9f9e2e36-51c4-4ab4-acaf-3b871ab83455 expires@2024-05-26T00:19:18.00Z',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:4d55d60e-ab4b-4004-9598-6522e1d8b3e6',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:157e5b6f-7d68-4621-a4e1-997f32cd6156']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:217c7568-0c0e-4dd3-ae5c-ebccfdbca40a',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Dr Cruz Malpique 37"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 6,
#   'dataProvider': 'cmp',
#   'description': 'Avenida da Cidade de Xangai',
#   'location': '{"type": "Point", "coordinates": [-8.633243423, 41.173066776]}',
#   'occupiedSpotNumber': 4,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:8a92afaa-6cc6-5a46-a435-229737a2b69d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:54169327-cec8-5e2e-8293-8fb83ede86b5',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:5d142a10-d92c-53c3-9f0c-9741625fef47',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:e3cf1741-b1a0-523a-94d1-0eb5c5ce2f27']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:6581862a-8a3d-4f88-ac41-21c2822a129a',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R D Joao Coutinho 31"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Engenheiro Ferreira Dias',
#   'location': '{"type": "Point", "coordinates": [-8.645910132, 41.175012239]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:d42b149d-bf29-5ba8-9479-d1d296025ee4']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:c1a10275-36f5-41ef-b8c1-8f4b82286518',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Bartolomeu Velho 889"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Diogo Botelho',
#   'location': '{"type": "Point", "coordinates": [-8.671428372, 41.153835315]}',
#   'occupiedSpotNumber': 1,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:7e29576a-ab65-5bac-8d54-9c52883e45af']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:a6718cbb-d23c-4b05-8d58-67f6c8c67516',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Passeio Alegre 784"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 6,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Passeio Alegre',
#   'location': '{"type": "Point", "coordinates": [-8.670062339, 41.148509657]}',
#   'occupiedSpotNumber': 4,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:a3f7e73e-8d10-4789-bf16-f2fa9fb5dcd0',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:6f250e77-525b-4436-840f-db114f479e8e expires@2024-05-26T13:16:34.00Z',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:ca1537ca-8951-4915-acd8-7abcfedd6055 expires@2024-05-26T13:19:34.00Z',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:4bd3d1cf-aecc-4843-9b5d-141405e45bc9 expires@2024-05-26T13:16:57.00Z']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:56da646c-e07e-4e61-9424-2020a0d321a4',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Do Ouro 902 - 1072"}',
# ...
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 2,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Santos Pousada',
#   'location': '{"type": "Point", "coordinates": [-8.599815538, 41.153055812]}',
#   'occupiedSpotNumber': 8,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:44c95e15-6d94-569b-9145-c393c994ed3c',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:bb7073c8-4b2e-596d-8284-beec6b1ecb7d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:f668e547-0c87-4644-a4c9-eb5234369946 expires@2024-05-25T23:12:54.00Z',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:ef13b429-3d51-524a-a490-b1b97e41bb9a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:b666feed-eb31-5732-a623-64700218656a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:d70539ea-a129-5abe-ad7e-9f9747082a9e',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:5ac01a01-afee-4aec-83f2-ee657547227d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:467eeb4e-dc56-4868-948a-4b58e9eb65ab']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:5ce38c3d-4ce4-4199-b93c-e4b5bc8cc299',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R D Pedro V 62-66-104"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 6,
#   'dataProvider': 'cmp',
#   'description': 'Rua de D. Pedro V',
#   'location': '{"type": "Point", "coordinates": [-8.632474669, 41.14749908]}',
#   'occupiedSpotNumber': 4,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:9eae46c1-f21e-5eae-91b4-a91adecde9b6',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:45a2b0ac-4d82-545c-8888-564ddba4fcfd',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:8e056d62-0455-5575-8c79-ad11185e3976',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:b3948793-1315-546d-b02a-b6b974448eb3']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:50ab03e9-da68-40b9-89c9-7ea34c99745c',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Esplanada Do Castelo 83"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 8,
#   'dataProvider': 'cmp',
#   'description': 'Avenida de D. Carlos I',
#   'location': '{"type": "Point", "coordinates": [-8.674832833, 41.148151508]}',
#   'occupiedSpotNumber': 2,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::bicycle:circ:61a31257-5b3e-4779-80cc-93bdddffdcef',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:0032e6ef-c7a5-4afe-bfd4-0e971f52eb87 expires@2024-05-26T10:24:54.00Z']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:a8ec7f24-00ab-481e-aefa-87b9fd0d8766',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Ant\\u00f3nio Carneiro 79"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 6,
#   'dataProvider': 'cmp',
#   'description': 'Rua de António Carneiro',
#   'location': '{"type": "Point", "coordinates": [-8.593049126, 41.147232654]}',
#   'occupiedSpotNumber': 4,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:4e8a94ad-9660-56df-a62b-6c94773aed8f',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:f3345ced-3de0-5d45-b74e-c66acbc75fbe',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:24570b87-c368-4f39-b0cb-8f4969b91aec',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:9171929f-ef8f-4917-af01-068f026f6bfd']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:cf81d56a-3c3a-42e0-bfe2-1a43d67b3371',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Av Do Bessa 158 C"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 8,
#   'dataProvider': 'cmp',
#   'description': 'Rua François Guichard',
#   'location': '{"type": "Point", "coordinates": [-8.642013564, 41.165243224]}',
#   'occupiedSpotNumber': 2,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:cae396ca-a061-598e-8b35-9a46bbc7d204',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:bad46e31-96f5-4a42-9346-c7358a06574b']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:6a433005-c41e-4c27-b59e-ae33f8e6af37',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Rua Of\\u00e9lia Diogo da Costa 45"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 3,
#   'dataProvider': 'cmp',
#   'description': 'Rua Ofélia Diogo da Costa',
#   'location': '{"type": "Point", "coordinates": [-8.631730984, 41.158708355]}',
#   'occupiedSpotNumber': 7,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:738fc67f-bb74-5a38-b54f-24eee4129cdd',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:03706810-cb6e-437b-a8e3-6e04b024ec10',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:fe4acd41-5f9d-48b1-b999-215d9ba9f5bf',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:1befbcd3-b1cf-4135-bf1d-3ef6292b9012',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:21a08a9d-713e-46b4-8b51-8a2b1dab9276',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:d2b30f26-805f-4687-91ad-6616b185b48c',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:29519b31-78f8-590e-91b6-7267304cdba9']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:60e262d5-5e45-4d11-9670-139d4a4b25cb',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Deniz Jacinto 90"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 10,
#   'dataProvider': 'cmp',
#   'description': 'Alameda da Cruz Vermelha Portuguesa',
#   'location': '{"type": "Point", "coordinates": [-8.574213738, 41.173690905]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 10,
#   'vehicle_ids': []},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:075af092-334c-4ee9-a8e0-c322e7c5ee0d',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Lg Dr Tito Fontes 155"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 7,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Gonçalo Cristóvão',
#   'location': '{"type": "Point", "coordinates": [-8.608400618, 41.153417784]}',
#   'occupiedSpotNumber': 3,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:9ef1d5b8-52c5-5b93-a9e5-71b6014bfe99',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:bdf72784-5032-55b9-bb38-699fa854c5e7',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:dd31fcfa-7223-4c1a-951b-f11c1ddb67b5']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:e47dc0b2-0500-43f9-a5a2-19db52e16f0b',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Pc Francisco Sa Carneiro 293"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 8,
#   'dataProvider': 'cmp',
#   'description': 'Praça de Francisco Sá Carneiro',
#   'location': '{"type": "Point", "coordinates": [-8.591973414, 41.162961063]}',
#   'occupiedSpotNumber': 2,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:96bfe9ea-9026-4c95-b912-c934d0f50b8f',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:3cd838b5-1a73-4cea-be51-902f9fe5a0ee']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:5a32462c-cf57-4888-9f6d-7868b753030e',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Bonjoia 691 CASA 1"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 8,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Bonjóia',
#   'location': '{"type": "Point", "coordinates": [-8.582666525, 41.151231711]}',
#   'occupiedSpotNumber': 2,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:bea008eb-6f65-469a-9f3e-f5109955b902 expires@2024-05-25T22:33:11.00Z',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:0145760d-8eff-4eb5-8d8d-165cb857f06e expires@2024-05-25T22:32:36.00Z']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:5e7ede01-7e20-41b2-96e2-880d97fc8a5b',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Heroismo 48"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 8,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Heroísmo',
#   'location': '{"type": "Point", "coordinates": [-8.589705522, 41.147062448]}',
#   'occupiedSpotNumber': 2,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:e072c7a2-9acd-5bbd-8552-91c4314ad2e5',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:568a5491-be16-4390-bc16-564d319e7dcb expires@2024-05-25T22:43:39.00Z']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:5d4b6ef9-8681-4fd4-b621-8a8ddc01a5ed',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Lg Alfandega 22"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 13,
#   'dataProvider': 'cmp',
#   'description': 'Largo da Alfândega',
#   'location': '{"type": "Point", "coordinates": [-8.621967077, 41.143987481]}',
#   'occupiedSpotNumber': 17,
#   'totalSpotNumber': 30,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:4b346a6e-b856-5b87-8d87-583cdc197c40',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:f3f49523-628f-5503-9b2f-04ec755be425',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:bc96abba-a91c-58c4-9cff-625f733ed8bf',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:8a45fb7b-4f42-4d8c-8d68-b60be7b9a9f1',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:87283bf1-cc12-5542-ac7e-007f5c6d1184',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:92995fe9-b1ed-5527-9233-5e0e8ba29834',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:c30fcdcb-bf24-443d-a0bd-bd0710f04ff5',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:0462db3d-ab71-4580-bae1-262667761a73',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:3bae0cec-aa59-4f8e-aa19-3978fa064aef',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:700ed3e1-a7ee-4cfa-b134-6affeb13ae7a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:8b151a8b-65f8-463d-81e6-74e3b01193fa',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:9132a53a-e567-4b02-9de3-b8e4388270e1',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:932d633f-eb31-480e-8210-1190a0c07972',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:964bae5c-22ea-4792-b8b9-1c00d0d8f39d',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:8dc8a1e0-2af6-486c-b873-3a0d42253855',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:cc385fd6-deeb-48d5-8bf1-ca59368699f0',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:d138544c-8006-5d81-b3e7-13b896b848c0']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:b8d167eb-ea39-4c79-9b9e-b3b31e3742ed',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Mouzinho Da Silveira 171"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 2,
#   'dataProvider': 'cmp',
#   'description': 'Rua de Mouzinho da Silveira',
#   'location': '{"type": "Point", "coordinates": [-8.612945993, 41.143725813]}',
#   'occupiedSpotNumber': 8,
#   'totalSpotNumber': 10,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:19d61ca2-e38e-4851-8735-efdf0eca7542',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:a3e940b0-43e2-5e03-bf79-0dc261df2382',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:0ab9a522-7e5e-4583-b08e-36dc1260c125',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:ef1424c5-e16f-4d8e-9926-c28de1043296',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:faa700b4-55a0-526b-aa3e-6902e23ea7c8',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:08bbf76d-24f2-4bdb-bec0-74e2a294f53a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::bicycle:bird:29982d7d-e2e3-4e7e-9b8e-77130da6ca90',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::bicycle:bird:130de210-1df5-4f99-9727-93c05007b637']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:fa3f8cb7-16a5-467e-832a-b81764cc0105',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Rua do Clube dos Fenianos 4000-407"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 14,
#   'dataProvider': 'cmp',
#   'description': 'Praça do General Humberto Delgado',
#   'location': '{"type": "Point", "coordinates": [-8.611032331, 41.149669782]}',
#   'occupiedSpotNumber': 6,
#   'totalSpotNumber': 20,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:circ:12e65a3c-8c32-4928-89f9-640a57ed2580',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:c49d16c5-c43f-46cb-9d70-ac1296cca98a',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:9e47a03e-2726-5065-8c3a-1e9e5a2172ce',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:e89209ad-b780-51f4-b1db-58744a2d87e6',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:be4a3b84-f90d-4c69-8069-0cfd8a54e2a7',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:b89f95ca-422b-4aeb-9eea-0b6ffb2e9934']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:41374df4-821a-420e-995e-1b44a6cd771e',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "R Inf D Henrique 36"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 12,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Infante D. Henrique',
#   'location': '{"type": "Point", "coordinates": [-8.614237467, 41.141235151]}',
#   'occupiedSpotNumber': 4,
#   'totalSpotNumber': 16,
#   'vehicle_ids': ['urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:cd67e764-f5c0-566e-b1ba-62b6d83414ee',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bolt:f177f315-17f1-54d2-969c-0298b59724cd',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:4398a8b8-b9a7-46d6-ba12-af5c6361837f expires@2024-05-26T10:24:55.00Z',
#    'urn:ngsi-ld:Vehicle:porto:free_bike::scooter:bird:b3e9b6b9-da2b-40a7-8271-aaa973909114']},
#  {'id': 'urn:ngsi-ld:OnStreetParking:porto:cmp:d27f8439-9115-4eaa-86e0-e9509ba2bc5a',
#   'type': 'OnStreetParking',
#   'address': '{"addressCountry": null, "addressLocality": null, "addressRegion": null, "postOfficeBoxNumber": null, "postalCode": null, "streetAddress": "Tv Nova Sintra 55"}',
#   'allowedVehicleType': ['twoWheeledVehicle'],
#   'availableSpotNumber': 9,
#   'dataProvider': 'cmp',
#   'description': 'Rua do Barão de Nova Sintra',
#   'location': '{"type": "Point", "coordinates": [-8.590482486, 41.145089847]}',
#   'occupiedSpotNumber': 0,
#   'totalSpotNumber': 9,
#   'vehicle_ids': []}]

# %%
# Define schema for the DataFrame
schema = StructType([
        StructField('id', StringType(), True),
        StructField('type', StringType(), True),
        StructField('address', StringType(), True),
        StructField('allowedVehicleType', ArrayType(StringType()), True),
        StructField('availableSpotNumber', IntegerType(), True),
        StructField('dataProvider', StringType(), True),
        StructField('description', StringType(), True),
        StructField('location', StringType(), True),
        StructField('occupiedSpotNumber', IntegerType(), True),
        StructField('totalSpotNumber', IntegerType(), True),
        StructField('vehicle_ids', ArrayType(StringType()), True)
    ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Define schema for the DataFrame
# ----> 2 schema = StructType([
#       3         StructField('id', StringType(), True),
#       4         StructField('type', StringType(), True),
#       5         StructField('address', StringType(), True),
#       6         StructField('allowedVehicleType', ArrayType(StringType()), True),
#       7         StructField('availableSpotNumber', IntegerType(), True),
#       8         StructField('dataProvider', StringType(), True),
#       9         StructField('description', StringType(), True),
#      10         StructField('location', StringType(), True),
#      11         StructField('occupiedSpotNumber', IntegerType(), True),
#      12         StructField('totalSpotNumber', IntegerType(), True),
#      13         StructField('vehicle_ids', ArrayType(StringType()), True)
#      14     ])
#
# NameError: name 'StructType' is not defined

# %%
# Define the MinIO endpoint URL and access keys
minio_endpoint = "http://localhost:9000"
access_key = "admin"
secret_key = "password123"

# Define the bucket name and object name
bucket_name = "test"
output_path = f"s3a://{bucket_name}/output_data.parquet"

# Configure Spark session
spark = SparkSession.builder \
    .appName('Write Parquet to MinIO') \
    .config("spark.hadoop.fs.s3a.access.key", access_key) \
    .config("spark.hadoop.fs.s3a.secret.key", secret_key) \
    .config("spark.hadoop.fs.s3a.endpoint", minio_endpoint) \
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
    .config("spark.hadoop.fs.s3a.path.style.access", "true") \
    .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
    .getOrCreate()
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 24/05/25 00:46:44 WARN Utils: Your hostname, Surface-DSO resolves to a loopback address: 127.0.1.1; using 172.31.77.62 instead (on interface eth0)
# 24/05/25 00:46:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/25 00:46:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Create a Spark DataFrame from JSON data
df = spark.createDataFrame(transformed_data, schema)

# Print schema and data
df.printSchema()
df.show()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- allowedVehicleType: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- availableSpotNumber: integer (nullable = true)
#  |-- dataProvider: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- occupiedSpotNumber: integer (nullable = true)
#  |-- totalSpotNumber: integer (nullable = true)
#  |-- vehicle_ids: array (nullable = true)
#  |    |-- element: string (containsNull = true)
# +--------------------+---------------+--------------------+-------------------+-------------------+------------+--------------------+--------------------+------------------+---------------+--------------------+
# |                  id|           type|             address| allowedVehicleType|availableSpotNumber|dataProvider|         description|            location|occupiedSpotNumber|totalSpotNumber|         vehicle_ids|
# +--------------------+---------------+--------------------+-------------------+-------------------+------------+--------------------+--------------------+------------------+---------------+--------------------+
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 10|         cmp|Praça de Mouzinho...|{"type": "Point",...|                 0|             10|                  []|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  2|         cmp|Passeio das Virtudes|{"type": "Point",...|                 8|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  3|         cmp|Campo dos Mártire...|{"type": "Point",...|                 7|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  8|         cmp|     Pátio do Bolhão|{"type": "Point",...|                 2|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  8|         cmp|Rua do Engenheiro...|{"type": "Point",...|                 2|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  9|         cmp|Rua de D. João Co...|{"type": "Point",...|                 1|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  5|         cmp|  Rua de Júlio Dinis|{"type": "Point",...|                 5|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 10|         cmp|Rua da Infanta D....|{"type": "Point",...|                 0|             10|                  []|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  2|         cmp| Avenida da Boavista|{"type": "Point",...|                 8|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  7|         cmp|Alameda de Eça de...|{"type": "Point",...|                 3|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  9|         cmp|Rua de Álvares Ca...|{"type": "Point",...|                 1|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 10|         cmp|Rua de 31 de Janeiro|{"type": "Point",...|                 0|             10|                  []|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  9|         cmp|        Rua de Vilar|{"type": "Point",...|                 1|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 10|         cmp|Rua de Mouzinho d...|{"type": "Point",...|                 0|             10|                  []|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 12|         cmp|Avenida de D. Car...|{"type": "Point",...|                 3|             15|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 10|         cmp|Rua do Professor ...|{"type": "Point",...|                 0|             10|                  []|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  9|         cmp|Rua Tareija Vaz d...|{"type": "Point",...|                11|             20|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 10|         cmp|Avenida do Marech...|{"type": "Point",...|                 0|             10|                  []|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  1|         cmp|Rua de Gonçalo Cr...|{"type": "Point",...|                 9|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  6|         cmp|Rua de Santa Cata...|{"type": "Point",...|                 4|             10|[urn:ngsi-ld:Vehi...|
# +--------------------+---------------+--------------------+-------------------+-------------------+------------+--------------------+--------------------+------------------+---------------+--------------------+
# only showing top 20 rows

# %%
df.select("description", "location", "availableSpotNumber", "occupiedSpotNumber","totalSpotNumber").show()
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+-------------------+------------------+---------------+
# |         description|            location|availableSpotNumber|occupiedSpotNumber|totalSpotNumber|
# +--------------------+--------------------+-------------------+------------------+---------------+
# |Praça de Mouzinho...|{"type": "Point",...|                 10|                 0|             10|
# |Passeio das Virtudes|{"type": "Point",...|                  2|                 8|             10|
# |Campo dos Mártire...|{"type": "Point",...|                  3|                 7|             10|
# |     Pátio do Bolhão|{"type": "Point",...|                  8|                 2|             10|
# |Rua do Engenheiro...|{"type": "Point",...|                  8|                 2|             10|
# |Rua de D. João Co...|{"type": "Point",...|                  9|                 1|             10|
# |  Rua de Júlio Dinis|{"type": "Point",...|                  5|                 5|             10|
# |Rua da Infanta D....|{"type": "Point",...|                 10|                 0|             10|
# | Avenida da Boavista|{"type": "Point",...|                  2|                 8|             10|
# |Alameda de Eça de...|{"type": "Point",...|                  7|                 3|             10|
# |Rua de Álvares Ca...|{"type": "Point",...|                  9|                 1|             10|
# |Rua de 31 de Janeiro|{"type": "Point",...|                 10|                 0|             10|
# |        Rua de Vilar|{"type": "Point",...|                  9|                 1|             10|
# |Rua de Mouzinho d...|{"type": "Point",...|                 10|                 0|             10|
# |Avenida de D. Car...|{"type": "Point",...|                 12|                 3|             15|
# |Rua do Professor ...|{"type": "Point",...|                 10|                 0|             10|
# |Rua Tareija Vaz d...|{"type": "Point",...|                  9|                11|             20|
# |Avenida do Marech...|{"type": "Point",...|                 10|                 0|             10|
# |Rua de Gonçalo Cr...|{"type": "Point",...|                  1|                 9|             10|
# |Rua de Santa Cata...|{"type": "Point",...|                  6|                 4|             10|
# +--------------------+--------------------+-------------------+------------------+---------------+
# only showing top 20 rows

# %%
# Write the DataFrame to MinIO in Parquet format
df.write.mode('overwrite').parquet(output_path)
# Out:
# 24/05/24 00:01:41 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 24/05/24 00:01:41 WARN BasicProfileConfigLoader: Your profile name includes a 'profile ' prefix. This is considered part of the profile name in the Java SDK, so you will need to include this prefix in your profile name when you reference this profile from your Java code.
# 24/05/24 00:01:42 WARN BasicProfileConfigLoader: Your profile name includes a 'profile ' prefix. This is considered part of the profile name in the Java SDK, so you will need to include this prefix in your profile name when you reference this profile from your Java code.
# 24/05/24 00:01:44 WARN BasicProfileConfigLoader: Your profile name includes a 'profile ' prefix. This is considered part of the profile name in the Java SDK, so you will need to include this prefix in your profile name when you reference this profile from your Java code.

# %% [markdown]
# ## Testing spark to read the parquet file created in the bucket

# %%
### USING THE SAME SESSION AS ABOVE FOR SAVING ###
# Read Parquet file from MinIO
df = spark.read.schema(schema).parquet(output_path)

# Show the DataFrame schema and content
df.printSchema()
df.show()
# Out:
# 24/05/25 00:49:07 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 24/05/25 00:49:07 WARN BasicProfileConfigLoader: Your profile name includes a 'profile ' prefix. This is considered part of the profile name in the Java SDK, so you will need to include this prefix in your profile name when you reference this profile from your Java code.
# 24/05/25 00:49:08 WARN BasicProfileConfigLoader: Your profile name includes a 'profile ' prefix. This is considered part of the profile name in the Java SDK, so you will need to include this prefix in your profile name when you reference this profile from your Java code.
# 24/05/25 00:49:10 WARN BasicProfileConfigLoader: Your profile name includes a 'profile ' prefix. This is considered part of the profile name in the Java SDK, so you will need to include this prefix in your profile name when you reference this profile from your Java code.
# root
#  |-- id: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- allowedVehicleType: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- availableSpotNumber: integer (nullable = true)
#  |-- dataProvider: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- occupiedSpotNumber: integer (nullable = true)
#  |-- totalSpotNumber: integer (nullable = true)
#  |-- vehicle_ids: array (nullable = true)
#  |    |-- element: string (containsNull = true)
# +--------------------+---------------+--------------------+-------------------+-------------------+------------+--------------------+--------------------+------------------+---------------+--------------------+
# |                  id|           type|             address| allowedVehicleType|availableSpotNumber|dataProvider|         description|            location|occupiedSpotNumber|totalSpotNumber|         vehicle_ids|
# +--------------------+---------------+--------------------+-------------------+-------------------+------------+--------------------+--------------------+------------------+---------------+--------------------+
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  3|         cmp|Avenida de Montev...|{"type": "Point",...|                 7|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  7|         cmp| Rua da Constituição|{"type": "Point",...|                 3|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  5|         cmp|Praça de Nove de ...|{"type": "Point",...|                 5|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  2|         cmp|Avenida de Vasco ...|{"type": "Point",...|                 8|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 10|         cmp|Avenida do Marech...|{"type": "Point",...|                 0|             10|                  []|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 10|         cmp|      Rua das Cruzes|{"type": "Point",...|                 0|             10|                  []|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 10|         cmp|      Rua do Rosário|{"type": "Point",...|                 0|             10|                  []|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  8|         cmp|Rua Actor João Gu...|{"type": "Point",...|                 2|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 10|         cmp|Rua do Dr. Plácid...|{"type": "Point",...|                10|             20|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  9|         cmp|       Rua de Camões|{"type": "Point",...|                 1|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  2|         cmp|Avenida da Cidade...|{"type": "Point",...|                 8|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  7|         cmp| Rua do Campo Alegre|{"type": "Point",...|                 3|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 -2|         cmp|Rua Henrique de S...|{"type": "Point",...|                12|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  6|         cmp|Rua do Dr. Ricard...|{"type": "Point",...|                 4|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  7|         cmp|      Rua de S. Tomé|{"type": "Point",...|                 3|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                -10|         cmp|Praça do Exército...|{"type": "Point",...|                20|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  7|         cmp|Rua do Dr. Ricard...|{"type": "Point",...|                 3|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                  7|         cmp|Rua de Manuel Pin...|{"type": "Point",...|                 3|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 -1|         cmp|Avenida de Montev...|{"type": "Point",...|                11|             10|[urn:ngsi-ld:Vehi...|
# |urn:ngsi-ld:OnStr...|OnStreetParking|{"addressCountry"...|[twoWheeledVehicle]|                 -1|         cmp|Rua Nova da Alfân...|{"type": "Point",...|                21|             20|[urn:ngsi-ld:Vehi...|
# +--------------------+---------------+--------------------+-------------------+-------------------+------------+--------------------+--------------------+------------------+---------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Transformations

# %%
location_schema = StructType([
    StructField('type', StringType(), True),
    StructField('coordinates', ArrayType(StringType()), True),
    StructField('metadata', StructType([]), True)
])

# Extract the JSON from the 'location' column
df = df.withColumn('location_json', from_json(col('location'), location_schema))

# Select and create new columns from the extracted JSON
df = df.withColumn('latitude', col('location_json.coordinates').getItem(0)) \
       .withColumn('longitude', col('location_json.coordinates').getItem(1))

df = df.drop('location')

# Strip spaces from the description column
df = df.withColumn('description', trim(col('description')))

# %%
# Show the DataFrame schema and content
df_to_agg = df.select("description", 'latitude', 'longitude', "availableSpotNumber", "occupiedSpotNumber","totalSpotNumber")

# %%
# Aggregate spots by location, round means
df_agg = df_to_agg.groupBy('description', 'latitude', 'longitude').agg(
    mean('availableSpotNumber').alias('mean_available_spots'),
    mean('occupiedSpotNumber').alias('mean_occupied_spots'),
    median('availableSpotNumber').alias('median_available_spots'),
    median('occupiedSpotNumber').alias('median_occupied_spots'),
)
df_agg.show(50, truncate=False)
# Out:
# [Stage 3:>                                                          (0 + 1) / 1]
# +-----------------------------------+------------+------------+--------------------+-------------------+----------------------+---------------------+
# |description                        |latitude    |longitude   |mean_available_spots|mean_occupied_spots|median_available_spots|median_occupied_spots|
# +-----------------------------------+------------+------------+--------------------+-------------------+----------------------+---------------------+
# |                                   |-8.662276771|41.150084663|10.0                |0.0                |10.0                  |0.0                  |
# |Alameda da Cruz Vermelha Portuguesa|-8.574213738|41.173690905|10.0                |0.0                |10.0                  |0.0                  |
# |Alameda das Antas                  |-8.58632669 |41.163312325|10.0                |0.0                |10.0                  |0.0                  |
# |Alameda de Eça de Queirós          |-8.593701737|41.162499468|7.0                 |3.0                |7.0                   |3.0                  |
# |Avenida da Boavista                |-8.624695365|41.157261198|2.0                 |8.0                |2.0                   |8.0                  |
# |Avenida da Boavista                |-8.627676305|41.157588559|6.0                 |4.0                |6.0                   |4.0                  |
# |Avenida da Boavista                |-8.633587814|41.158744895|7.0                 |3.0                |7.0                   |3.0                  |
# |Avenida da Boavista                |-8.637669357|41.159259565|10.0                |0.0                |10.0                  |0.0                  |
# |Avenida da Boavista                |-8.637739791|41.15943441 |7.0                 |3.0                |7.0                   |3.0                  |
# |Avenida da Boavista                |-8.643538875|41.160409563|2.0                 |8.0                |2.0                   |8.0                  |
# |Avenida da Boavista                |-8.657953699|41.162616734|4.0                 |6.0                |4.0                   |6.0                  |
# |Avenida da Boavista                |-8.680363263|41.166608877|6.0                 |4.0                |6.0                   |4.0                  |
# |Avenida da Cidade de Xangai        |-8.632128858|41.170008323|2.0                 |8.0                |2.0                   |8.0                  |
# |Avenida da Cidade de Xangai        |-8.633243423|41.173066776|9.0                 |1.0                |9.0                   |1.0                  |
# |Avenida da Cidade de Xangai        |-8.634705542|41.175361269|1.0                 |9.0                |1.0                   |9.0                  |
# |Avenida da França                  |-8.628401357|41.161035047|9.0                 |1.0                |9.0                   |1.0                  |
# |Avenida das Congostas              |-8.63447778 |41.178858314|-2.0                |12.0               |-2.0                  |12.0                 |
# |Avenida das Congostas              |-8.63495518 |41.175756312|3.0                 |7.0                |3.0                   |7.0                  |
# |Avenida de Camilo                  |-8.594742465|41.148858784|9.0                 |1.0                |9.0                   |1.0                  |
# |Avenida de D. Carlos I             |-8.667488714|41.147478277|12.0                |3.0                |12.0                  |3.0                  |
# |Avenida de D. Carlos I             |-8.671695839|41.147592201|3.0                 |7.0                |3.0                   |7.0                  |
# |Avenida de D. Carlos I             |-8.674832833|41.148151508|1.0                 |9.0                |1.0                   |9.0                  |
# |Avenida de Fernão de Magalhães     |-8.583959799|41.175406971|10.0                |0.0                |10.0                  |0.0                  |
# |Avenida de Fernão de Magalhães     |-8.588441731|41.165558683|9.0                 |1.0                |9.0                   |1.0                  |
# |Avenida de Gustavo Eiffel          |-8.604642422|41.141870922|10.0                |0.0                |10.0                  |0.0                  |
# |Avenida de Montevideu              |-8.686476285|41.164338004|-1.0                |11.0               |-1.0                  |11.0                 |
# |Avenida de Montevideu              |-8.687839703|41.166750461|3.0                 |7.0                |3.0                   |7.0                  |
# |Avenida de Rodrigues de Freitas    |-8.6005512  |41.145849604|4.0                 |6.0                |4.0                   |6.0                  |
# |Avenida de Vasco da Gama           |-8.656738849|41.17080079 |2.0                 |8.0                |2.0                   |8.0                  |
# |Avenida do Brasil                  |-8.679049193|41.153871738|11.0                |4.0                |11.0                  |4.0                  |
# |Avenida do Brasil                  |-8.681679107|41.15699378 |5.0                 |5.0                |5.0                   |5.0                  |
# |Avenida do Brasil                  |-8.683382744|41.15900654 |4.0                 |6.0                |4.0                   |6.0                  |
# |Avenida do Dr. Antunes Guimarães   |-8.657354936|41.170203618|5.0                 |5.0                |5.0                   |5.0                  |
# |Avenida do Dr. Antunes Guimarães   |-8.659102073|41.168182383|6.0                 |4.0                |6.0                   |4.0                  |
# |Avenida do Dr. Antunes Guimarães   |-8.659701577|41.167478819|7.0                 |3.0                |7.0                   |3.0                  |
# |Avenida do Dr. Antunes Guimarães   |-8.662388389|41.16423563 |4.0                 |6.0                |4.0                   |6.0                  |
# |Avenida do Marechal Gomes da Costa |-8.664725158|41.158446577|8.0                 |2.0                |8.0                   |2.0                  |
# |Avenida do Marechal Gomes da Costa |-8.665500202|41.157867376|10.0                |0.0                |10.0                  |0.0                  |
# |Avenida do Marechal Gomes da Costa |-8.667438985|41.157103703|10.0                |0.0                |10.0                  |0.0                  |
# |Avenida do Marechal Gomes da Costa |-8.667533902|41.157341027|10.0                |0.0                |10.0                  |0.0                  |
# |Avenida do Marechal Gomes da Costa |-8.671648458|41.155453438|10.0                |0.0                |10.0                  |0.0                  |
# |Avenida do Parque                  |-8.671938189|41.165742054|1.0                 |9.0                |1.0                   |9.0                  |
# |Campo dos Mártires da Pátria       |-8.615845901|41.145280424|2.0                 |18.0               |2.0                   |18.0                 |
# |Campo dos Mártires da Pátria       |-8.617372732|41.145244637|3.0                 |7.0                |3.0                   |7.0                  |
# |Esplanada do Castelo               |-8.671515946|41.148982451|10.0                |0.0                |10.0                  |0.0                  |
# |Esplanada do Castelo               |-8.675892288|41.14934843 |4.0                 |6.0                |4.0                   |6.0                  |
# |Largo da Alfândega                 |-8.621967077|41.143987481|17.0                |13.0               |17.0                  |13.0                 |
# |Largo da Lapa                      |-8.611472089|41.156971483|6.0                 |4.0                |6.0                   |4.0                  |
# |Largo de Ferreira Lapa             |-8.628460854|41.155610565|7.0                 |3.0                |7.0                   |3.0                  |
# |Largo de Soares dos Reis           |-8.596018438|41.146066365|5.0                 |5.0                |5.0                   |5.0                  |
# +-----------------------------------+------------+------------+--------------------+-------------------+----------------------+---------------------+
# only showing top 50 rows

# %%
# Create a postgres connection
import psycopg2

# PostgreSQL connection details
host = 'localhost'
port = 5432
database = 'postgres'
user = 'postgres'
password = 'password123'

# Create a connection
conn = psycopg2.connect(
    host=host,
    port=port,
    database=database,
    user=user,
    password=password
)

# Test the connection
if conn.status == psycopg2.extensions.STATUS_READY:
    print("Connected to PostgreSQL successfully!")
else:
    print("Failed to connect to PostgreSQL.")
c
# Out:
# Connected to PostgreSQL successfully!

# %%
# Create a sql table matching spark dataframe with autoincremental ID
create_table_query = """
CREATE TABLE IF NOT EXISTS parking_spots (
    id SERIAL PRIMARY KEY,
    description VARCHAR(255),
    latitude VARCHAR(255),
    longitude VARCHAR(255),
    mean_available_spots FLOAT,
    mean_occupied_spots FLOAT,
    median_available_spots FLOAT,
    median_occupied_spots FLOAT
);
"""

# %%
# Close connection to database
conn.close()

# %%
spark.stop()

# %%
from pyspark.sql import SparkSession

# Path to the PostgreSQL JDBC driver JAR file
jdbc_jar_path = '/opt/spark-3.5.1-bin-hadoop3/jars/postgresql-42.7.3.jar'

# Create Spark session with the correct path to the JAR file
spark = SparkSession.builder \
    .appName('PostgreSQL Connection') \
    .config('spark.jars', jdbc_jar_path) \
    .getOrCreate()

# Configure PostgreSQL connection details
host = 'localhost'
port = 5432
database = 'postgres'
user = 'postgres'
password = 'password123'

# Define the JDBC URL
url = f'jdbc:postgresql://{host}:{port}/{database}'

# Define the table name
table_name = 'parking_spots'

# Assuming df_agg is already defined somewhere in your script.
# Example: df_agg = spark.read.csv('path_to_csv_file').groupBy(...).agg(...)

# Write the df_agg DataFrame to the specified PostgreSQL table
df_agg.write \
    .format('jdbc') \
    .option('url', url) \
    .option('dbtable', table_name) \
    .option('user', user) \
    .option('password', password) \
    .option('driver', 'org.postgresql.Driver') \
    .mode('overwrite')\
    .save()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[32], line 37
#      23 table_name = 'parking_spots'
#      25 # Assuming df_agg is already defined somewhere in your script.
#      26 # Example: df_agg = spark.read.csv('path_to_csv_file').groupBy(...).agg(...)
#      27
#      28 # Write the df_agg DataFrame to the specified PostgreSQL table
#      29 df_agg.write \
#      30     .format('jdbc') \
#      31     .option('url', url) \
#      32     .option('dbtable', table_name) \
#      33     .option('user', user) \
#      34     .option('password', password) \
#      35     .option('driver', 'org.postgresql.Driver') \
#      36     .mode('overwrite')\
# ---> 37     .save()
#
# File /opt/spark-3.5.1-bin-hadoop3/python/pyspark/sql/readwriter.py:1461, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
#    1459     self.format(format)
#    1460 if path is None:
# -> 1461     self._jwrite.save()
#    1462 else:
#    1463     self._jwrite.save(path)
#
# File /opt/spark-3.5.1-bin-hadoop3/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/spark-3.5.1-bin-hadoop3/python/pyspark/errors/exceptions/captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     177 def deco(*a: Any, **kw: Any) -> Any:
#     178     try:
# --> 179         return f(*a, **kw)
#     180     except Py4JJavaError as e:
#     181         converted = convert_exception(e.java_exception)
#
# File /opt/spark-3.5.1-bin-hadoop3/python/lib/py4j-0.10.9.7-src.zip/py4j/protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     324 value = OUTPUT_CONVERTER[type](answer[2:], gateway_client)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#     330     raise Py4JError(
#     331         "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332         format(target_id, ".", name, value))
#
# Py4JJavaError: An error occurred while calling o301.save.
# : java.lang.ClassNotFoundException: org.postgresql.Driver
# 	at java.net.URLClassLoader.findClass(URLClassLoader.java:382)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:418)
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:351)
# 	at org.apache.spark.sql.execution.datasources.jdbc.DriverRegistry$.register(DriverRegistry.scala:46)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JDBCOptions.$anonfun$driverClass$1(JDBCOptions.scala:103)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JDBCOptions.$anonfun$driverClass$1$adapted(JDBCOptions.scala:103)
# 	at scala.Option.foreach(Option.scala:407)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JDBCOptions.<init>(JDBCOptions.scala:103)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JdbcOptionsInWrite.<init>(JDBCOptions.scala:254)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JdbcOptionsInWrite.<init>(JDBCOptions.scala:258)
# 	at org.apache.spark.sql.execution.datasources.jdbc.JdbcRelationProvider.createRelation(JdbcRelationProvider.scala:47)
# 	at org.apache.spark.sql.execution.datasources.SaveIntoDataSourceCommand.run(SaveIntoDataSourceCommand.scala:48)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult$lzycompute(commands.scala:75)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult(commands.scala:73)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.executeCollect(commands.scala:84)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.$anonfun$applyOrElse$1(QueryExecution.scala:107)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$6(SQLExecution.scala:125)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:201)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId$1(SQLExecution.scala:108)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:900)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:66)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.applyOrElse(QueryExecution.scala:107)
# 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$eagerlyExecuteCommands$1.applyOrElse(QueryExecution.scala:98)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDownWithPruning$1(TreeNode.scala:461)
# 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(origin.scala:76)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDownWithPruning(TreeNode.scala:461)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDownWithPruning(LogicalPlan.scala:32)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning(AnalysisHelper.scala:267)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning$(AnalysisHelper.scala:263)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:32)
# 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:32)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:437)
# 	at org.apache.spark.sql.execution.QueryExecution.eagerlyExecuteCommands(QueryExecution.scala:98)
# 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted$lzycompute(QueryExecution.scala:85)
# 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted(QueryExecution.scala:83)
# 	at org.apache.spark.sql.execution.QueryExecution.assertCommandExecuted(QueryExecution.scala:142)
# 	at org.apache.spark.sql.DataFrameWriter.runCommand(DataFrameWriter.scala:859)
# 	at org.apache.spark.sql.DataFrameWriter.saveToV1Source(DataFrameWriter.scala:388)
# 	at org.apache.spark.sql.DataFrameWriter.saveInternal(DataFrameWriter.scala:361)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:248)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# 	at java.lang.Thread.run(Thread.java:748)
